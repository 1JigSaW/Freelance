# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('Офисы Продажа 2021г.xlsx')

# %%
df.head()
# Out:
#        id                                        Ссылка Тип сделки   Город  \
# 0  952449  https://afy.ru/moskva/kupit-ofis/60000988915    Продажа  Москва
# 1  947282  https://afy.ru/moskva/kupit-ofis/60000992295    Продажа  Москва
# 2  946735  https://afy.ru/moskva/kupit-ofis/60001016772    Продажа  Москва
# 3  146030  https://afy.ru/moskva/kupit-ofis/60001016774    Продажа  Москва
# 4  874272  https://afy.ru/moskva/kupit-ofis/60001017648    Продажа  Москва
#
#                 Сегмент Класс  Общая площадь           Этаж Состояние отделки  \
# 0  Офисная недвижимость     C          392.0  Второй и выше               NaN
# 1  Офисная недвижимость     C          195.0  Второй и выше               NaN
# 2  Офисная недвижимость     C          233.0         Первый               NaN
# 3  Офисная недвижимость     A          162.0  Второй и выше               NaN
# 4  Офисная недвижимость     A          232.0  Второй и выше               NaN
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'Ссылка', 'Тип сделки', 'Город', 'Сегмент', 'Класс',
#        'Общая площадь', 'Этаж', 'Состояние отделки', 'Доступ', 'Парковка',
#        'Красная линия', 'Отдельный вход', 'Витринные окна', 'ЖД ветка',
#        'Отопление', 'Холодильная камера', 'ГПМ', 'Наличие ограждения', 'Адрес',
#        'Дата создания', 'Удельная цена', 'Цена', 'Описание', 'Тип здания',
#        'Ссылка на скриншот', 'Номер телефона', 'longitude', 'latitude', 'Зоны',
#        'Большие_Зоны', 'Кластеры', 'Кластеры по географии',
#        'Расстояние до центра, м.', 'Ближайшая школа, м.',
#        'Ближайший детсад, м.', 'Ближайшее кладбище, м.', 'Ближайший парк, м.',
#        'Ближайшая остановка, м.', 'Ближайшая больница, м.',
#        'Ближайшее метро, м.'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id  Общая площадь  ЖД ветка  Удельная цена          Цена  \
# count  1.333600e+04   13336.000000       0.0   1.333600e+04  1.333600e+04
# mean   1.503758e+06     539.654652       NaN   1.211562e+05  7.313939e+07
# std    9.720680e+05    1997.929099       NaN   8.167937e+05  4.451284e+08
# min    1.142570e+05       4.000000       NaN   6.986591e+01  5.500000e+03
# 25%    9.066788e+05      61.000000       NaN   4.500000e+04  3.900000e+06
# 50%    9.387485e+05     131.600006       NaN   6.896552e+04  9.000000e+06
# 75%    2.323731e+06     342.000000       NaN   1.100000e+05  2.684250e+07
# max    5.029957e+06   62000.000000       NaN   6.005222e+07  2.300000e+10
#
#           longitude      latitude  Расстояние до центра, м.  \
# count  12300.000000  12300.000000              6.973000e+03
# mean      54.007899     54.508864              1.305707e+04
# std       20.050092      3.488752              2.442326e+05
# ...

# %%
df_c = df[df['Класс'] == 'C']
df_c.head(10)
# Out:
#          id                                        Ссылка Тип сделки   Город  \
# 0    952449  https://afy.ru/moskva/kupit-ofis/60000988915    Продажа  Москва
# 1    947282  https://afy.ru/moskva/kupit-ofis/60000992295    Продажа  Москва
# 2    946735  https://afy.ru/moskva/kupit-ofis/60001016772    Продажа  Москва
# 5    946767  https://afy.ru/moskva/kupit-ofis/60001026386    Продажа  Москва
# 6    958717  https://afy.ru/moskva/kupit-ofis/60001026378    Продажа  Москва
# 9   1246514  https://afy.ru/moskva/kupit-ofis/60001046078    Продажа  Москва
# 11   946869  https://afy.ru/moskva/kupit-ofis/60001058541    Продажа  Москва
# 12   959216  https://afy.ru/moskva/kupit-ofis/60001085312    Продажа  Москва
# 13   959412  https://afy.ru/moskva/kupit-ofis/60001075190    Продажа  Москва
# 14   959076  https://afy.ru/moskva/kupit-ofis/60001114586    Продажа  Москва
#
#                  Сегмент Класс  Общая площадь           Этаж  \
# ...

# %%
df_c['Удельная стоимость'] = round(df_c['Цена'] / df_c['Общая площадь'], 2)
# Out:
# <ipython-input-29-1a95eb34f827>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['Удельная стоимость'] = round(df_c['Цена'] / df_c['Общая площадь'], 2)

# %%
df_c
# Out:
#            id                                        Ссылка Тип сделки  \
# 0      952449  https://afy.ru/moskva/kupit-ofis/60000988915    Продажа
# 1      947282  https://afy.ru/moskva/kupit-ofis/60000992295    Продажа
# 2      946735  https://afy.ru/moskva/kupit-ofis/60001016772    Продажа
# 5      946767  https://afy.ru/moskva/kupit-ofis/60001026386    Продажа
# 6      958717  https://afy.ru/moskva/kupit-ofis/60001026378    Продажа
# ...       ...                                           ...        ...
# 13331  946622  https://afy.ru/moskva/kupit-ofis/60000820509    Продажа
# 13332  946895  https://afy.ru/moskva/kupit-ofis/60000821391    Продажа
# 13333  946681  https://afy.ru/moskva/kupit-ofis/60000821410    Продажа
# 13334  945642  https://afy.ru/moskva/kupit-ofis/60000845663    Продажа
# 13335  958696  https://afy.ru/moskva/kupit-ofis/60000914693    Продажа
#
#         Город               Сегмент Класс  Общая площадь           Этаж  \
# ...

# %%
X = df_c[['Общая площадь', 'Расстояние до центра, м.']].values
y = df_c['Удельная стоимость'].values

# %%
plt.scatter(X, y)
plt.plot(X, slr.predict(X), color='red', linewidth=2);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-2abe9535d75b> in <module>
#       1 plt.scatter(X, y)
# ----> 2 plt.plot(X, slr.predict(X), color='red', linewidth=2);
#
# NameError: name 'slr' is not defined
