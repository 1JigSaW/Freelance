# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/da-python/python-for-data-analytics/blob/main/Lesson2/hometask/HH-api-hometask.ipynb)

# %% [markdown]
# # Задание
# * Скачать все вакансии СБЕРа с ХХ (у апи есть ограничение в 2000, а также captcha подумайте как их можно обойти)
# * Извлеките все описания этих вакансий
# * Создайте аналогичный vacancy DataFrame только добавьте поле skills
# * Переведите даты публикаций в datetime
# * Постройте график опубликованных вакансий по датам
# * Переведите даты в дни недели, и определите день недели, в который больше всего публикуют вакансий
# * Найдите те вакансии с использованием python, которые вам интересны
# * Определите по полю skills какие навыки больше всего востребованы для этих вакансий
# * Постройте график наиболее востребованных навыков для аналитика данных

# %% [markdown]
# https://github.com/hhru/api

# %%
import requests
import json
from tqdm.auto import tqdm
from collections import defaultdict
import pickle
import pandas as pd

# %%
sber = '3529'
page = 1
num_per_page = 100
moscow = 1
url = f'https://api.hh.ru/vacancies?employer_id={sber}&page={page}&per_page={num_per_page}&area={moscow}'

# %%
res = requests.get(url)

# %%
res.json()
# Out:
# {'alternate_url': 'https://hh.ru/search/vacancy?area=1&control_flag=vacancyBlacklistJoinEnabled%3ATrue&employer_id=3529&enable_snippets=true&items_on_page=100&page=1',
#  'arguments': None,
#  'clusters': None,
#  'found': 1183,
#  'items': [{'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67986380/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67986380',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67986380',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-20T13:17:00+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67986380',
#    'insider_interview': None,
#    'name': 'Менеджер по продажам сложных продуктов',
#    'premium': False,
#    'published_at': '2022-07-20T13:17:00+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее образование (экономика\\финансы\\банки). Опыт работы в продажах\\сопровождении клиентов корпоративного бизнеса – не менее 2 лет. Знание продуктовой линейки...',
#     'responsibility': 'Обеспечение выполнения бизнес-плана по продажам закрепленных продуктов/клиентам/сегментам/территориям. Развитие отношений с Клиентами, развитие партнерских программ (поиск новых...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67986380?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/68122877/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68122877',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68122877',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-25T16:05:26+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '68122877',
#    'insider_interview': None,
#    'name': 'Директор Strategy Office',
#    'premium': False,
#    'published_at': '2022-07-25T16:05:26+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее образование. Опыт работы от 3 лет в аналогичной должности. Опыт в составлении бизнес-моделей.',
#     'responsibility': 'Организация разработки, внедрения и актуализации стратегии блока (план, бюджет внедрения стратегии; разработка КПЭ, мероприятий и инициатив, направленных на достижение целей...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/68122877?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/66912098/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66912098',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66912098',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-26T14:27:55+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '66912098',
#    'insider_interview': None,
#    'name': 'QA Engineer (СберДруг)',
#    'premium': False,
#    'published_at': '2022-07-26T14:27:55+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Уверенные знания Java Core. Умение разбираться и работать с чужим кодом. Опыт разработки автоматизированных тестов (Java). Будет плюсом: Опыт автоматизации...',
#     'responsibility': 'В основе проекта лежит автоматизированная система «ДРУГ», состоящая из следующих компонентов: web-интерфейс, мобильное приложение, REST-API и back-end...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/66912098?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '32к1',
#     'city': 'Москва',
#     'description': None,
#     'id': '731097',
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'metro': {'lat': 55.740544,
#      'line_id': '4',
#      'line_name': 'Филевская',
#      'lng': 37.5341,
#      'station_id': '4.73',
#      'station_name': 'Кутузовская'},
#     'metro_stations': [{'lat': 55.740544,
#       'line_id': '4',
#       'line_name': 'Филевская',
#       'lng': 37.5341,
#       'station_id': '4.73',
#       'station_name': 'Кутузовская'},
#      {'lat': 55.740833,
#       'line_id': '95',
#       'line_name': 'МЦК',
#       'lng': 37.533333,
#       'station_id': '95.536',
#       'station_name': 'Кутузовская'}],
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'street': 'Кутузовский проспект'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/68198680/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68198680',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68198680',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-27T12:18:46+0300',
#    'department': None,
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '68198680',
#    'insider_interview': None,
#    'name': 'Qa engineer',
#    'premium': False,
#    'published_at': '2022-07-27T12:18:46+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Нам нужны командные игроки которые с инженерной точностью подходят к решению поставленных задач и несут ответственность за принятые решения. ',
#     'responsibility': 'О продукте: Сервис, который позволит клиентам банка совместно вести финансы в удаленных каналах обслуживания (приложение и веб-версия "Сбербанк Онлайн"). '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/68198680?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '32к1',
#     'city': 'Москва',
#     'description': None,
#     'id': '731097',
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'metro': {'lat': 55.740544,
#      'line_id': '4',
#      'line_name': 'Филевская',
#      'lng': 37.5341,
#      'station_id': '4.73',
#      'station_name': 'Кутузовская'},
#     'metro_stations': [{'lat': 55.740544,
#       'line_id': '4',
#       'line_name': 'Филевская',
#       'lng': 37.5341,
#       'station_id': '4.73',
#       'station_name': 'Кутузовская'},
#      {'lat': 55.740833,
#       'line_id': '95',
#       'line_name': 'МЦК',
#       'lng': 37.533333,
#       'station_id': '95.536',
#       'station_name': 'Кутузовская'}],
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'street': 'Кутузовский проспект'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67734236/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67734236',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67734236',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-13T11:55:40+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67734236',
#    'insider_interview': None,
#    'name': 'Технический специалист дежурной смены',
#    'premium': False,
#    'published_at': '2022-07-13T11:55:40+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'shift', 'name': 'Сменный график'},
#    'snippet': {'requirement': 'Высшее образование/неоконченное высшее. Желателен опыт работы в сфере процессинговых систем. Желателен опыт работы с «бэк-офисной» обработкой. ',
#     'responsibility': 'Выполнение ежедневного цикла технологических процедур в процессинговых системах. Мониторинг согласованного уровня предоставления ИТ-услуг, своевременная регистрация инцидентов. Оповещение в установленном...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67734236?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67767117/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67767117',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67767117',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-14T11:01:33+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67767117',
#    'insider_interview': None,
#    'name': 'Менеджер по работе с международными партнерами (Дивизион Салют для бизнеса)',
#    'premium': False,
#    'published_at': '2022-07-14T11:01:33+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Опыт в продажах ИТ-продуктов от 3-х лет (опыт работы в компаниях-вендорах/системных интеграторах – как преимущество). ',
#     'responsibility': 'Поиском и привлечением новых партнеров компании. Участием в выставках, конференциях. Участием в формировании и согласовании стратегии развития партнерского канала продаж...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67767117?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '32',
#     'city': 'Москва',
#     'description': None,
#     'id': '6080840',
#     'lat': 55.740426,
#     'lng': 37.532071,
#     'metro': None,
#     'metro_stations': [],
#     'raw': 'Москва, Кутузовский проспект, 32',
#     'street': 'Кутузовский проспект'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67908794/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67908794',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67908794',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-19T11:32:28+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67908794',
#    'insider_interview': None,
#    'name': 'Стажер Sber AI Lab',
#    'premium': False,
#    'published_at': '2022-07-19T11:32:28+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 55000, 'gross': True, 'to': 57000},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Имеешь хорошие знания математики и алгоритмов. Умеешь писать на python и хорошо знаком со стандартными библиотеками(pandas, numpy, sklearn, pytorch...',
#     'responsibility': 'У тебя есть публикации в ведущих научных конференциях и журналах. Участвовал в DS соревнованиях Kaggle и пр.. Любишь изучать новые...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67908794?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/68254624/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68254624',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68254624',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-28T15:39:43+0300',
#    'department': None,
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '68254624',
#    'insider_interview': None,
#    'name': 'Senior strategy partner SberEducation',
#    'premium': False,
#    'published_at': '2022-07-28T15:39:43+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее образование (ТОП-ВУЗы). Наличие опыта работы в крупных международных консалтинговых компаниях или стратегическом подразделении образовательной индустрии обязательно. ',
#     'responsibility': 'Разработка и оценка выполнения стратегии индустрии образования. Внедрение лучших практик, инноваций и успешных бизнес-моделей. Организация разработки, внедрения и актуализации...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/68254624?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': None,
#     'city': 'Москва',
#     'description': None,
#     'id': '2894827',
#     'lat': 55.753215,
#     'lng': 37.622504,
#     'metro': None,
#     'metro_stations': [],
#     'raw': 'Москва',
#     'street': None},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67264564/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67264564',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67264564',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-26T11:48:29+0300',
#    'department': {'id': '3529-3529-stat', 'name': 'Сбер. Начало карьеры'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67264564',
#    'insider_interview': None,
#    'name': 'Клиентский менеджер прямых продаж',
#    'premium': False,
#    'published_at': '2022-07-26T11:48:29+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 98800, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': None,
#     'responsibility': 'Выезжать к клиентам на индивидуальные консультации. Проводить презентации сервисов Сбера на территории компаний-партнеров. Предлагать сервисы Сбера и помогать с...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67264564?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/66223607/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66223607',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66223607',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-21T17:52:19+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '66223607',
#    'insider_interview': None,
#    'name': 'С++ разработчик',
#    'premium': False,
#    'published_at': '2022-07-21T17:52:19+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Хорошее знание STL. Знание C и C++11/14/17. Разработка API для библиотек и программных компонентов. Опыт производства чистого...',
#     'responsibility': 'Разработка новых и развитие существующих биометрических систем. Адаптация разработанных решений по разные платформы. Взаимодействие с R&D, аналитиками, инженерами технической...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/66223607?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/66523856/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66523856',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66523856',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-05T18:51:27+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '66523856',
#    'insider_interview': None,
#    'name': 'Аналитик SQL',
#    'premium': False,
#    'published_at': '2022-07-05T18:51:27+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее образование (математика/физика/программирование/экономика). - Знания SQL. - Навыки работы с Python (приветствуется).',
#     'responsibility': 'Блок "Сеть продаж" курирует все физические каналы касания клиента с экосистемой (отделения, банкоматы, агентская сеть и тд). Мы разрабатываем и...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/66523856?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '32к1',
#     'city': 'Москва',
#     'description': None,
#     'id': '731097',
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'metro': {'lat': 55.740544,
#      'line_id': '4',
#      'line_name': 'Филевская',
#      'lng': 37.5341,
#      'station_id': '4.73',
#      'station_name': 'Кутузовская'},
#     'metro_stations': [{'lat': 55.740544,
#       'line_id': '4',
#       'line_name': 'Филевская',
#       'lng': 37.5341,
#       'station_id': '4.73',
#       'station_name': 'Кутузовская'},
#      {'lat': 55.740833,
#       'line_id': '95',
#       'line_name': 'МЦК',
#       'lng': 37.533333,
#       'station_id': '95.536',
#       'station_name': 'Кутузовская'}],
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'street': 'Кутузовский проспект'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/66893189/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66893189',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66893189',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-04T14:46:35+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '66893189',
#    'insider_interview': None,
#    'name': 'QA Engineer / Инженер по тестированию (Пассивы)',
#    'premium': False,
#    'published_at': '2022-07-04T14:46:35+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Опыт тестирования от 1.5 лет и опыт автоматизации тестирования. Знание SQL на уровне создания запросов. Понимание принципов реляционных и...',
#     'responsibility': 'Анализ требований на разработку. Оценка трудоемкости задач. Разработка тестовой модели, описание интеграционных, регрессионных и прочих сценариев. Системное, интеграционное, регрессионное тестирование...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/66893189?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/46023828/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/46023828',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=46023828',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-25T18:13:55+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '46023828',
#    'insider_interview': None,
#    'name': 'Системный администратор / junior devops инженер',
#    'premium': False,
#    'published_at': '2022-07-25T18:13:55+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Не менее 3 лет работы в сфере ИТ. Иметь представление об архитектурах приложений, интеграционных взаимодействиях, шлюзовых решениях. Понимание принципов DevOps...',
#     'responsibility': 'Администрирование и сопровождение автоматизированных систем. Приемка, внедрение новых версий, настройка АС, участие в DevOps процессах. Построение мониторинга компонентов АС, мониторинг...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/46023828?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67289493/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67289493',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67289493',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-29T16:19:55+0300',
#    'department': None,
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67289493',
#    'insider_interview': None,
#    'name': 'Технический менеджер проекта Compute',
#    'premium': False,
#    'published_at': '2022-07-29T16:19:55+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 400000, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Имеете опыт участия в инфраструктурных или продуктовых проектах. Обладаете аналитическими навыками, владеете Python или SQL. Умеете общаться на одном языке...',
#     'responsibility': 'Организовывать рабочие процессы команды и следить за их прозрачностью. Детально знать продукт: пользовательские сценарии, процессы релизов, его архитектуру, инструментарий вокруг...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67289493?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/66828400/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66828400',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66828400',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-12T11:23:55+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '66828400',
#    'insider_interview': None,
#    'name': 'Тестировщик (нагрузочное тестирование)',
#    'premium': False,
#    'published_at': '2022-07-12T11:23:55+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Опыт выполнения проектов по нагрузочному тестированию. Опыт работы с HP Performance Center/LoadRunner. Знание одного из языков программирования Java, C#...',
#     'responsibility': 'Организация и проведение нагрузочного тестирования системы аутентификации. Разработка высокопроизводительных эмуляторов и заглушек (Java). Разработка скриптов нагрузочного тестирования (LoadRunner, HTTP/MQ). '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/66828400?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '32к1',
#     'city': 'Москва',
#     'description': None,
#     'id': '731097',
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'metro': {'lat': 55.740544,
#      'line_id': '4',
#      'line_name': 'Филевская',
#      'lng': 37.5341,
#      'station_id': '4.73',
#      'station_name': 'Кутузовская'},
#     'metro_stations': [{'lat': 55.740544,
#       'line_id': '4',
#       'line_name': 'Филевская',
#       'lng': 37.5341,
#       'station_id': '4.73',
#       'station_name': 'Кутузовская'},
#      {'lat': 55.740833,
#       'line_id': '95',
#       'line_name': 'МЦК',
#       'lng': 37.533333,
#       'station_id': '95.536',
#       'station_name': 'Кутузовская'}],
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'street': 'Кутузовский проспект'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67764112/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67764112',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67764112',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-14T10:02:29+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67764112',
#    'insider_interview': None,
#    'name': 'Бизнес-аналитик',
#    'premium': False,
#    'published_at': '2022-07-14T10:02:29+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Аналитическое мышление и умение систематизировать информацию. Умение структурировать/формулировать и презентовать свои идеи. Хорошее владение аналитическими инструментами (как минимум обработка...',
#     'responsibility': 'E2E-подготовка презентаций - от сторилайна до оформления. Поиск аналитики, подготовка отчетов для коллегиальных органов банка. Бизнес-аналитика по...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67764112?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67527622/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67527622',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67527622',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-18T16:04:13+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67527622',
#    'insider_interview': None,
#    'name': 'Senior Frontend разработчик',
#    'premium': False,
#    'published_at': '2022-07-18T16:04:13+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Уверенное знание JavaScript, React JS, Redux будет плюсом, CSS, HTML. Опыт проектирования архитектуры приложения. Опыт написания Unit-тестов. ',
#     'responsibility': 'АС Депозитарий - автоматизированная система, обеспечивающая сбор и хранение информации о совершенных сделках с различными ценными бумагами (акции, облигации, фьючерсы, опционы...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67527622?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67354226/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67354226',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67354226',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-12T16:57:58+0300',
#    'department': {'id': '3529-3529-kiber', 'name': 'Сбер. Кибербезопасность'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67354226',
#    'insider_interview': None,
#    'name': 'Руководитель по ИБ (CISO)',
#    'premium': False,
#    'published_at': '2022-07-12T16:57:58+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'высшее образование по направлению подготовки (специальности) в ИБ или смежных областях. - опыт работы: 3–6 лет. - знание английского языка на...',
#     'responsibility': 'управление деятельностью организации в области ИБ. - разработка и реализация политики ИБ компании, адекватной бизнес\xadпроцессам компании. - внедрение и сопровождение средств...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67354226?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67463303/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67463303',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67463303',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-04T15:02:11+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67463303',
#    'insider_interview': None,
#    'name': 'Junior архитектор',
#    'premium': False,
#    'published_at': '2022-07-04T15:02:11+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 270000, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее образование. Понимание жизненного цикла разработки ПО. Опыт в проектировании высоконагруженных систем и решений в банках/FinTech-компаниях на позициях...',
#     'responsibility': 'Проведение оценки бизнес-инициатив по автоматизации на соответствие стандартам Банка по процессам зарплатных и социальных зачислений. Разработка и актуализация проектных...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67463303?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/68156330/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68156330',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68156330',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-26T13:57:57+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '68156330',
#    'insider_interview': None,
#    'name': 'Техник-электрик',
#    'premium': False,
#    'published_at': '2022-07-26T13:57:57+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Иметь среднее специальное (электротехническое) образование. Стаж работы в области эксплуатации и монтажа низковольтного оборудования 0,4 кВ не менее 3...',
#     'responsibility': 'Обеспечивает поддержание оборудования 0,4 кВ и сетей в исправном, работоспособном состоянии в соответствии с требованиями действующих нормативных документов. '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/68156330?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/66554726/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66554726',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66554726',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-22T10:20:48+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '66554726',
#    'insider_interview': None,
#    'name': 'Data analyst',
#    'premium': False,
#    'published_at': '2022-07-22T10:20:48+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Хорошие знания SQL, опыт работы с одной из реляционной БД - Oracle/PostgreSQL/mySQL/MS SQL Server. Уверенная работа с Python. ',
#     'responsibility': 'Проведение ad-hoc аналитики на данных рекламы (Hive, Spark, SQL). Визуализация отчетности в BI инструментах (SuperSet, Qlik). Работа с алгоритмами...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/66554726?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67975245/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67975245',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67975245',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-20T10:29:02+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67975245',
#    'insider_interview': None,
#    'name': 'Менеджер по защите персональных данных',
#    'premium': False,
#    'published_at': '2022-07-20T10:29:02+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Образование в области информационной безопасности, юриспруденции. Опыт работы в области организации обработки и защиты ПДн не менее 1 года. ',
#     'responsibility': 'Разработка локальных нормативных документов Банка по вопросам обработки и защиты ПДн. Экспертиза внутренних нормативных документов, договорной и иной документации, связанной...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67975245?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '10',
#     'city': 'Москва',
#     'description': None,
#     'id': '2404332',
#     'lat': 55.696001,
#     'lng': 37.625504,
#     'metro': {'lat': 55.69,
#      'line_id': '95',
#      'line_name': 'МЦК',
#      'lng': 37.618889,
#      'station_id': '95.532',
#      'station_name': 'Верхние Котлы'},
#     'metro_stations': [{'lat': 55.69,
#       'line_id': '95',
#       'line_name': 'МЦК',
#       'lng': 37.618889,
#       'station_id': '95.532',
#       'station_name': 'Верхние Котлы'},
#      {'lat': 55.682099,
#       'line_id': '9',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'lng': 37.620917,
#       'station_id': '9.85',
#       'station_name': 'Нагатинская'}],
#     'raw': 'Москва, Новоданиловская набережная, 10',
#     'street': 'Новоданиловская набережная'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67042024/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67042024',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67042024',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-21T14:42:21+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67042024',
#    'insider_interview': None,
#    'name': 'ETL разработчик/ Data engineer',
#    'premium': False,
#    'published_at': '2022-07-21T14:42:21+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Фундаментальные знания принципов построения распределенных систем хранения и обработки данных. Наличие опыта работы с экосистемой Hadoop (HDFS, Hive, Impala, HBase...',
#     'responsibility': 'Участие в сложных интеграционных проектах по развитию гибридного DWH Сбербанка (Hadoop, Oracle, Kafka) в роли разработчика или лидера разработки. '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
# ...
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/68073467/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68073467',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68073467',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-22T15:51:35+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '68073467',
#    'insider_interview': None,
#    'name': 'QA Team Lead',
#    'premium': False,
#    'published_at': '2022-07-22T15:51:35+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Опыт в работы в качестве QA от 5 лет, управление командой QA от 1 года. Понимание разных видов тестирования, знание...',
#     'responsibility': 'Заниматься управлением, наймом и развитием команды QA. Обучение, onboarding и менторинг. Разработка и реализация стратегии, методик тестирования на проекте. '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/68073467?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/54825644/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54825644',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54825644',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-20T12:16:30+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '54825644',
#    'insider_interview': None,
#    'name': 'Программист Python',
#    'premium': False,
#    'published_at': '2022-07-20T12:16:30+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее образование (техническое будет преимуществом). - Опыт не менее 2-х лет в IT. - Знание back-end разработки. - Работа с Python. - ',
#     'responsibility': 'Разрабатывать сценарии автоматизации настройки Linux-серверов, модулей Ansibe (Python). - Автоматизировать и развивать процессы выдачи, конфигурирования и сопровождения Linux-серверов. - '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/54825644?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67903179/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67903179',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67903179',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-19T10:16:16+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67903179',
#    'insider_interview': None,
#    'name': 'Frontend разработчик',
#    'premium': False,
#    'published_at': '2022-07-19T10:16:16+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Следование основным Agile принципам и нацеленность на результат. Требования: Опыт работы в роли разработчика от 1 года. Владение стеком проекта...',
#     'responsibility': 'Наша команда создает микросервисные решения, позволяющие Сберу комплексно оценивать факторы риска и принимать верные решения при взаимодействии с партнерами и...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67903179?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/68233316/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68233316',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68233316',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-28T11:08:36+0300',
#    'department': None,
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '68233316',
#    'insider_interview': None,
#    'name': 'Руководитель команды / техлид SberInfra.IAM',
#    'premium': False,
#    'published_at': '2022-07-28T11:08:36+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 480000, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Знаете язык программирования Java или Go. Программировали в POSIX-окружении. Имеете опыт работы с системами авторизации. Умеете писать надежный код...',
#     'responsibility': 'Управления ключевыми сущностями ресурсно-сервисной модели облачной инфраструктуры. Управления ролями и аккаунтами. Интеграции с корпоративными системами аутентификации. Реализаций механизмов авторизации...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/68233316?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '10',
#     'city': 'Москва',
#     'description': None,
#     'id': '146841',
#     'lat': 55.695905,
#     'lng': 37.625361,
#     'metro': {'lat': 55.70961,
#      'line_id': '9',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'lng': 37.622569,
#      'station_id': '9.142',
#      'station_name': 'Тульская'},
#     'metro_stations': [{'lat': 55.70961,
#       'line_id': '9',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'lng': 37.622569,
#       'station_id': '9.142',
#       'station_name': 'Тульская'}],
#     'raw': 'Москва, Новоданиловская набережная, 10',
#     'street': 'Новоданиловская набережная'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/68286711/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68286711',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68286711',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-29T14:28:16+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '68286711',
#    'insider_interview': None,
#    'name': 'Java-разработчик',
#    'premium': False,
#    'published_at': '2022-07-29T14:28:16+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Знание стека Spring JavaEE. Опыт разработки Rest API, знание протокола HTTP. Уверенно Java Core (Collection, Multithreading). Опыт работы с базами...',
#     'responsibility': 'Проектирование/разработка/внедрение Restful Api. Первичное тестирование разрабатываемых программных модулей. Рефакторинг существующего кода с целью его оптимизации. Code review.'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/68286711?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67545309/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67545309',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67545309',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-06T15:39:42+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67545309',
#    'insider_interview': None,
#    'name': 'Старший юрист по интеллектуальной собственности',
#    'premium': False,
#    'published_at': '2022-07-06T15:39:42+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Наличие высшего юридического образования. Опыт работы не менее 7 лет по юридической специальности, из них в юридической службе консалтинговой компании...',
#     'responsibility': 'Заниматься правовым сопровождением деятельности Банка в области маркетинга и коммуникаций – полное сопровождение рекламных активностей (рекламные рассылки, акции, мероприятия, форумы, реклама...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67545309?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67913330/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67913330',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67913330',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-19T12:43:41+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67913330',
#    'insider_interview': None,
#    'name': 'ИТ-аналитик / Руководитель проектов в Центр технологического консалтинга',
#    'premium': False,
#    'published_at': '2022-07-19T12:43:41+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Опыт разработки и согласования бизнес-требований. Умение писать структурированные технические документы (БТ, ФТ, спецификации). Развитые коммуникационные навыки, умение самостоятельно найти...',
#     'responsibility': 'Общение с заказчиками и сбор требований (функциональных и нефункциональных) по автоматизируемым процессам. Анализ и разработка решения для интеграции собранных требований...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67913330?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67603630/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67603630',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67603630',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-08T11:28:16+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67603630',
#    'insider_interview': None,
#    'name': 'Руководитель отдела разработки',
#    'premium': False,
#    'published_at': '2022-07-08T11:28:16+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Имеете опыт принятия архитектурных решений. Имеете опыт руководства техническими специалистами. Имеете опыт выявления и закрытия технологических рисков. Принимали участие во...',
#     'responsibility': 'Нести ответственность за техническое состояние и стабильную работу АС. Взаимодействовать с проектными командами. Принимать руководящие решения, касающиеся сотрудников. '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67603630?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []}],
#  'page': 1,
#  'pages': 12,
#  'per_page': 100}

# %%
vacancies = res.json()
num_pages = vacancies.get('pages')
num_pages
# Out:
# 12

# %%
v = vacancies.get('items')

# %%
v[0]['accept_temporary']
# Out:
# False

# %%
vacancies.keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'per_page', 'page', 'clusters', 'arguments', 'alternate_url'])

# %%
vacancies = res.json()
num_pages = vacancies.get('pages')
vacancy_ids = [el.get('id') for el in vacancies.get('items')]
data = pd.DataFrame(vacancies.get('items'))
data.head(5)
# Out:
#          id  premium                                    name  \
# 0  67986380    False  Менеджер по продажам сложных продуктов
# 1  68122877    False                Директор Strategy Office
# 2  66912098    False                  QA Engineer (СберДруг)
# 3  68198680    False                             Qa engineer
# 4  67734236    False   Технический специалист дежурной смены
#
#                                           department  has_test  \
# 0  {'id': '3529-3529-prof', 'name': 'Сбер для экс...     False
# 1  {'id': '3529-3529-prof', 'name': 'Сбер для экс...     False
# 2         {'id': '3529-3529-it', 'name': 'Сбер. IT'}     False
# 3                                               None     False
# 4         {'id': '3529-3529-it', 'name': 'Сбер. IT'}     False
#
#    response_letter_required  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#                                                 area salary  \
# 0  {'id': '1', 'name': 'Москва', 'url': 'https://...   None
# 1  {'id': '1', 'name': 'Москва', 'url': 'https://...   None
# 2  {'id': '1', 'name': 'Москва', 'url': 'https://...   None
# 3  {'id': '1', 'name': 'Москва', 'url': 'https://...   None
# 4  {'id': '1', 'name': 'Москва', 'url': 'https://...   None
#
#                                  type  \
# 0  {'id': 'open', 'name': 'Открытая'}
# 1  {'id': 'open', 'name': 'Открытая'}
# 2  {'id': 'open', 'name': 'Открытая'}
# 3  {'id': 'open', 'name': 'Открытая'}
# 4  {'id': 'open', 'name': 'Открытая'}
#
#                                              address  ...  \
# 0                                               None  ...
# 1                                               None  ...
# 2                                               None  ...
# 3  {'city': 'Москва', 'street': 'Кутузовский прос...  ...
# 4  {'city': 'Москва', 'street': 'Кутузовский прос...  ...
#
#                     alternate_url relations  \
# 0  https://hh.ru/vacancy/67986380        []
# 1  https://hh.ru/vacancy/68122877        []
# 2  https://hh.ru/vacancy/66912098        []
# 3  https://hh.ru/vacancy/68198680        []
# 4  https://hh.ru/vacancy/67734236        []
#
#                                             employer  \
# 0  {'id': '3529', 'name': 'СБЕР', 'url': 'https:/...
# 1  {'id': '3529', 'name': 'СБЕР', 'url': 'https:/...
# 2  {'id': '3529', 'name': 'СБЕР', 'url': 'https:/...
# 3  {'id': '3529', 'name': 'СБЕР', 'url': 'https:/...
# 4  {'id': '3529', 'name': 'СБЕР', 'url': 'https:/...
#
#                                              snippet  contacts  \
# 0  {'requirement': 'Высшее образование (экономика...      None
# 1  {'requirement': 'Высшее образование. Опыт рабо...      None
# 2  {'requirement': 'Уверенные знания Java Core. У...      None
# 3  {'requirement': 'Нам нужны командные игроки ко...      None
# 4  {'requirement': 'Высшее образование/неоконченн...      None
#
#                                     schedule working_days  \
# 0   {'id': 'fullDay', 'name': 'Полный день'}           []
# 1   {'id': 'fullDay', 'name': 'Полный день'}           []
# 2   {'id': 'fullDay', 'name': 'Полный день'}           []
# 3   {'id': 'fullDay', 'name': 'Полный день'}           []
# 4  {'id': 'shift', 'name': 'Сменный график'}           []
#
#   working_time_intervals working_time_modes accept_temporary
# 0                     []                 []            False
# 1                     []                 []            False
# 2                     []                 []            False
# 3                     []                 []            False
# 4                     []                 []            False
#
# [5 rows x 29 columns]

# %%
vacancies.keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'per_page', 'page', 'clusters', 'arguments', 'alternate_url'])

# %%
vnum  = vacancies.get('pages')

# %%
all_vacancy_ids= []
for i in tqdm(range(vnum)):
    url = f'https://api.hh.ru/vacancies?employer_id={sber}&page={i}&per_page={num_per_page}&area={moscow}'
    res = requests.get(url)
    vacancies = res.json()
    vacancy_ids = [el.get('id') for el in vacancies.get('items')]
    all_vacancy_ids.extend(vacancy_ids)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]

# %%
len(all_vacancy_ids)
# https://api.hh.ru/vacancies/66634517
# Out:
# 1183

# %%
url = f'https://api.hh.ru/vacancies/{all_vacancy_ids[0]}'

# %%
res = requests.get(url)

# %%
data2 = []
for i in tqdm(range(len(all_vacancy_ids))): # забираем по id вакансий
    url = f'https://api.hh.ru/vacancies/{all_vacancy_ids[i]}'
    res = requests.get(url)
    res = res.json()
    data2.append(res)
# Out:
#   0%|          | 0/1183 [00:00<?, ?it/s]

# %%
df = pd.DataFrame(data2)
df.head(1)
# Out:
#          id  premium                            billing_type relations  \
# 0  55415805    False  {'id': 'standard', 'name': 'Стандарт'}        []
#
#                              name insider_interview  response_letter_required  \
# 0  Менеджер по работе с клиентами              None                     False
#
#                                                 area  \
# 0  {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                               salary  \
# 0  {'from': 98800, 'to': None, 'currency': 'RUR',...
#
#                                  type  ...  \
# 0  {'id': 'open', 'name': 'Открытая'}  ...
#
#                                  apply_alternate_url  has_test  test  \
# 0  https://hh.ru/applicant/vacancy_response?vacan...     False  None
#
#                     alternate_url working_days working_time_intervals  \
# 0  https://hh.ru/vacancy/55415805           []                     []
#
#   working_time_modes accept_temporary languages immediate_redirect_url
# 0                 []            False        []                    NaN
#
# [1 rows x 48 columns]

# %%
df = pd.DataFrame(data2, columns=['id', 'name', 'description', 'key_skills', 
                                  'published_at', 'created_at', 'salary'])

# %%
df.head(5)
# Out:
#          id                                               name  \
# 0  55415805                     Менеджер по работе с клиентами
# 1  67349462                        Старший клиентский менеджер
# 2  55415496                  Клиентский менеджер прямых продаж
# 3  45790891  Менеджер по работе с ключевыми клиентами малог...
# 4  67911334                               Ассистент Управления
#
#                                          description  \
# 0  <p>Сбер — лучший работодатель России. У нас бо...
# 1  <p>Сбер — лучший работодатель России. У нас бо...
# 2  <p>Сбер — лучший работодатель России. У нас бо...
# 3  <p>Сбер — лучший работодатель России. У нас бо...
# 4  <p><strong>Обязанности:</strong></p> <ul> <li>...
#
#                                           key_skills  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'name': 'Прямые продажи'}, {'name': 'Финансо...
# 4                                                 []
#
#                published_at                created_at  \
# 0  2022-07-27T13:48:51+0300  2022-07-27T13:48:51+0300
# 1  2022-07-25T11:48:47+0300  2022-07-25T11:48:47+0300
# 2  2022-07-29T11:49:00+0300  2022-07-29T11:49:00+0300
# 3  2022-07-28T14:40:40+0300  2022-07-28T14:40:40+0300
# 4  2022-07-19T12:11:11+0300  2022-07-19T12:11:11+0300
#
#                                               salary
# 0  {'from': 98800, 'to': None, 'currency': 'RUR',...
# 1  {'from': 98800, 'to': None, 'currency': 'RUR',...
# 2  {'from': 98800, 'to': None, 'currency': 'RUR',...
# 3  {'from': 119300, 'to': None, 'currency': 'RUR'...
# 4                                               None

# %%
df['description'] = df['description'].str.replace(r'\<[^\>]*\>', ' ')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
df['description']
# Out:
# 0        Сбер — лучший работодатель России. У нас боле...
# 1        Сбер — лучший работодатель России. У нас боле...
# 2        Сбер — лучший работодатель России. У нас боле...
# 3        Сбер — лучший работодатель России. У нас боле...
# 4         Обязанности:      Аналитика по Управлению за...
#                               ...
# 1178     Сбер — лучший работодатель России. У нас боле...
# 1179     Сбер — лучший работодатель России. У нас боле...
# 1180     Сбер — лучший работодатель России. У нас боле...
# 1181     Сбер — лучший работодатель России. У нас боле...
# 1182     Сбер — лучший работодатель России. У нас боле...
# Name: description, Length: 1183, dtype: object

# %%
import numpy as np
df_skills = pd.DataFrame(df)
df_skills = df_skills.rename(columns={'key_skills':'skills'})

# %%
arr_skill = []
for skill in df_skills['skills']:
    if skill:
        temp_arr = []
        for item in skill:
            temp_arr.append(item["name"])
        arr_skill.append(", ".join(temp_arr))
    else: 
        arr_skill.append(None)

# %%
arr_skill
# Out:
# [None,
#  None,
#  None,
#  ['Прямые продажи',
#   'Финансовый анализ',
#   'Клиентоориентированность',
#   'Развитие продаж',
#   'Ведение переговоров',
#   'Активные продажи',
#   'Навыки продаж',
#   'Проведение презентаций',
#   'Работа с ключевыми клиентами',
#   'Работа с юридическими лицами'],
#  None,
#  None,
#  None,
#  ['UX', 'Figma', 'Adobe Photoshop', 'UI', 'Дизайн интерфейсов', 'Дизайн'],
#  ['Работа в команде',
#   'Грамотная речь',
#   'Организаторские навыки',
#   'Консультирование',
#   'Обучение и развитие',
#   'Внутренние коммуникации',
#   'Деловая коммуникация',
#   'Умение легко находить контакт с людьми',
#   'Составление отчетности',
#   'Способность быстро обучаться',
#   'Уверенное знание ПК',
#   'HR'],
#  ['MS Visio', 'SAP BW', 'Бизнес-анализ', 'SQL', 'Управление проектами'],
#  ['Активные продажи', 'Холодные продажи'],
#  ['HTML', 'CSS', 'JavaScript'],
#  ['Python', 'Pandas', 'PyTorch', 'Machine Learning'],
#  None,
#  None,
#  ['Холодные продажи',
#   'Поиск и привлечение клиентов',
#   'Активные продажи',
#   'Ведение переговоров',
#   'Проведение презентаций',
#   'Навыки продаж',
#   'Телефонные переговоры',
#   'Продажи юридическим лицам',
#   'Работа с юридическими лицами',
#   'Навыки переговоров',
#   'Корпоративные продажи',
#   'Клиентоориентированность'],
#  None,
#  None,
#  ['Активные продажи', 'Холодные продажи'],
#  ['Управление проектами',
#   'Работа в команде',
#   'MS PowerPoint',
#   'MS Project Expert',
#   'Информационные технологии'],
#  ['Ведение переговоров',
#   'Заключение договоров',
#   'Закупки',
#   'Работа с большим объемом информации',
#   'MS PowerPoint'],
#  ['Анализ ФХД',
#   'Финансовый анализ',
#   'Экономический анализ',
#   'Работа с юридическими лицами',
#   'Работа с большим объемом информации'],
#  ['JavaScript', 'Git', 'Redux', 'CSS', 'HTML'],
#  ['Работа в команде',
#   'Грамотная речь',
#   'Деловая переписка',
#   'Проведение презентаций',
#   'Юрист договорного права',
#   'Составление договоров',
#   'Методолог',
#   'Управление недвижимостью',
#   'Юриспруденция',
#   'АСУ',
#   'Умение работать в условиях многозадачности'],
#  ['Активные продажи',
#   'Продвижение бренда',
#   'Разработка маркетинговой стратегии',
#   'Маркетинговые исследования',
#   'Обучение персонала',
#   'Продуктовый маркетинг',
#   'B2B маркетинг'],
#  ['Adobe Photoshop', 'Figma', 'Adobe Illustrator', 'UI', 'UX'],
#  ['JavaScript', 'Redux', 'Git', 'CSS3', 'TypeScript', 'React'],
#  ['Внутренние коммуникации',
#   'Информирование сотрудников об изменениях в компании',
#   'Работа в команде',
#   'Atlassian Jira',
#   'Организаторские навыки'],
#  None,
#  ['Python', 'Hive', 'Hadoop', 'Аналитическое мышление', 'Spark'],
#  ['SQL',
#   'Atlassian Jira',
#   'Atlassian Confluence',
#   'API',
#   'REST',
#   'Postman',
#   'Java',
#   'Selenium',
#   'Cucumber',
#   'Allure'],
#  ['Грамотная речь',
#   'Деловая коммуникация',
#   'Грамотность',
#   'Креативность',
#   'Написание текстов',
#   'PR'],
#  ['SolidWorks', 'AutoCAD', 'ГОСТ', 'ЕСКД'],
#  ['SolidWorks', 'AutoCAD', 'ГОСТ', 'ЕСКД'],
#  ['Пользователь ПК',
#   'Грамотная речь',
#   'Работа в команде',
#   'Умение работать в команде',
#   'Администрирование'],
#  None,
#  ['Психофизиолог', 'Психодиагностика', 'Клиническая психология'],
#  ['Планирование рабочего дня руководителя',
#   'Организация встреч',
#   'Административная поддержка руководителя',
#   'Исполнение личных поручений руководителя',
#   'Документооборот'],
#  ['Английский язык', 'Ведение переговоров'],
#  ['SQL', 'Python', 'Hadoop', 'Умение принимать решения', 'Data Analysis'],
#  ['Python', 'SCALA', 'Big Data', 'SQL', 'Java'],
#  ['MS PowerPoint', 'Adobe Illustrator', 'MS Excel', 'MS SQL'],
#  ['BPMN', 'SQL', 'XML', 'Бизнес-анализ'],
#  ['Грамотная речь', 'Работа с большим объемом информации', 'Работа с людьми'],
#  ['SQL', 'Linux', 'PyTorch', 'Ориентация на результат', 'C++'],
#  ['Организаторские навыки',
#   'Деловая коммуникация',
#   'Работа в команде',
#   'Организация мероприятий',
#   'Деловая переписка',
#   'Проектный менеджмент'],
#  ['Python'],
#  None,
#  None,
#  None,
#  ['Ведение переговоров',
#   'Работа в команде',
#   'Управление проектами',
#   'Организаторские навыки',
#   'Креативность',
#   'Стратегический консалтинг',
#   'Консалтинг'],
#  None,
#  None,
#  None,
#  ['VDI', 'Управление проектами', 'Виртуальные рабочие места', 'ИТ проекты'],
#  ['Проведение презентаций',
#   'Ведение переговоров',
#   'Организаторские навыки',
#   'Деловая коммуникация',
#   'Заключение договоров'],
#  None,
#  None,
#  ['Java',
#   'Test case',
#   'Тестирование',
#   'TestNG',
#   'Тестирование пользовательского интерфейса'],
#  None,
#  None,
#  ['Git', 'Qt', 'Linux', 'ООП', 'C++'],
#  None,
#  ['BPMN',
#   'UML',
#   'Atlassian Jira',
#   'XML',
#   'Atlassian Confluence',
#   'SOAP',
#   'JSON',
#   'SQL запросы'],
#  ['CSS', 'HTML', 'JavaScript', 'Adobe Photoshop', 'Figma'],
#  None,
#  ['Техническая документация', 'Методология', 'ITIL', 'ITSM', 'COBIT'],
#  ['JavaScript', 'TypeScript', 'React', 'Redux', 'HTML', 'CSS'],
#  ['Git', 'Spring Framework', 'Java', 'Английский язык', 'Kotlin'],
#  None,
#  None,
#  ['Ориентация на результат',
#   'Работа в команде',
#   'Управление проектами',
#   'Управление отношениями с клиентами',
#   'Проведение презентаций',
#   'Agile Project Management',
#   'Умение работать с людьми'],
#  ['Helpdesk', 'ITIL'],
#  None,
#  ['Python', 'MongoDB', 'SQL', 'JavaScript', 'Django Framework'],
#  None,
#  ['SQL', 'Python'],
#  ['C#', 'MS SQL Server', 'ASP.NET', 'Entity Framework', '.NET Framework'],
#  ['Работа в команде',
#   'Atlassian Jira',
#   'Atlassian Confluence',
#   'Умение принимать решения',
#   'Деловая коммуникация'],
#  None,
#  None,
#  ['Figma',
#   'Креативность',
#   'Навыки презентации',
#   'Проведение опросов',
#   'Организация и проведение фокус групп'],
#  None,
#  ['Работа в команде',
#   'Управление проектами',
#   'Обучение и развитие',
#   'Деловая коммуникация',
#   'Обучение персонала'],
#  ['Функциональное тестирование', 'Тестирование', 'SQL', 'XML', 'Postman'],
#  None,
#  ['Figma', 'UX', 'Adobe Photoshop', 'UI', 'Дизайн интерфейсов'],
#  ['Adobe Photoshop', 'Figma', 'MS PowerPoint', 'HTML', 'UI', 'CSS'],
#  None,
#  ['бэк офис',
#   'ковенанты',
#   'Calypso',
#   'Diasoft',
#   'Фондовый рынок',
#   'статические данные'],
#  ['Big Data', 'ETL', 'ORACLE', 'СУБД', 'CI', 'Bash', 'Java'],
#  ['Управление проектами',
#   'CRM',
#   'Управление отношениями с клиентами',
#   'Проектный менеджмент',
#   'Ориентация на результат'],
#  ['Postman',
#   'Функциональное тестирование',
#   'Fiddler',
#   'Тестирование',
#   'Обучение и развитие'],
#  ['MS PowerPoint',
#   'CRM',
#   'Деловая коммуникация',
#   'Проведение презентаций',
#   'Публичные выступления',
#   'Анализ инвестиционных проектов'],
#  None,
#  None,
#  None,
#  None,
#  ['JavaScript', 'CSS', 'HTML', 'Нейронные сети', 'Google Chrome'],
#  ['Python',
#   'Ориентация на результат',
#   'TDD',
#   'Soft skills',
#   'Работа с банками'],
#  None,
#  ['Git', 'Atlassian Jira', 'Java', 'Scrum', 'SQL'],
#  None,
#  ['Atlassian Jira',
#   'Atlassian Confluence',
#   'SQL',
#   'Функциональное тестирование',
#   'Oracle Pl/SQL'],
#  ['Microsoft Access', 'Мониторинг', 'SQL'],
#  ['Ведение переговоров',
#   'Английский язык',
#   'Поиск и привлечение клиентов',
#   'Развитие продаж',
#   'Испанский язык'],
#  ['Python', 'PyTorch', 'Machine Learning', 'Pandas', 'Numpy', 'Recsys'],
#  ['Английский язык',
#   'Подготовка презентаций',
#   'Проведение презентаций',
#   'Организация мероприятий',
#   'Управление проектами',
#   'Стратегический консалтинг',
#   'Education',
#   'EdTech'],
#  ['Проведение презентаций',
#   'Поиск и привлечение клиентов',
#   'Холодные продажи',
#   'Прямые продажи'],
#  None,
#  ['SQL', 'Python'],
#  ['SQL', 'JUnit', 'Agile', 'SOAP', 'Java'],
#  None,
#  ['MS PowerPoint',
#   'Аналитическое мышление',
#   'Подготовка презентаций',
#   'Работа с большим объемом информации',
#   'Анализ данных',
#   'MS Excel',
#   'keynote'],
#  ['Python', 'SQL', 'Linux'],
#  None,
#  ['JavaScript', 'Git', 'React', 'Redux', 'TypeScript'],
#  ['Информационная безопасность',
#   'Информационные технологии',
#   'Английский язык',
#   'Разработка и внедрение политик и процедур',
#   'Средства криптографической защиты информации',
#   'Технические средства информационной защиты',
#   'Аудит безопасности'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Appium',
#   'Kotlin',
#   'Английский язык',
#   'Креативность',
#   'Проведение тестирований'],
#  ['Функциональное тестирование', 'REST', 'Основы SQL'],
#  None,
#  ['Грейдинг',
#   'MS PowerPoint',
#   'Мотивация персонала',
#   'Лидерство',
#   'Управление бюджетом',
#   'Performance Management',
#   'Точность и внимательность к деталям'],
#  ['Docker', 'Работа с базами данных', 'Big Data', 'Управление временем'],
#  None,
#  ['Figma', 'UX', 'Работа в команде', 'UI', 'Android'],
#  ['PyTorch', 'Tensorflow', 'Python', 'Deep Learning', 'NLP'],
#  None,
#  None,
#  ['Atlassian Jira',
#   'Функциональное тестирование',
#   'SQL',
#   'Agile Project Management',
#   'Atlassian Confluence'],
#  None,
#  ['Bash',
#   'Atlassian Confluence',
#   'Atlassian Jira',
#   'Jenkins',
#   'Автоматизация'],
#  ['Python', 'Pandas', 'Numpy', 'SQL', 'Linux', 'ML', 'Deep Learning'],
#  None,
#  ['SQL', 'UML', 'BPMN', 'REST', 'XML'],
#  None,
#  None,
#  None,
#  None,
#  ['Python', 'Английский язык', 'Написание научных статей', 'Анализ данных'],
#  ['React', 'Redux', 'MobX', 'TypeScript', 'JavaScript', 'Jest'],
#  ['JavaScript', 'Git', 'CSS3', 'Redux', 'Node.js', 'HTML', 'Frontend'],
#  None,
#  ['Аналитическое мышление', 'UML', 'BPMN', 'MS PowerPoint', 'Анализ данных'],
#  None,
#  ['Python', 'SQL', 'Data Mining', 'Oracle BI', 'Анализ данных'],
#  ['UML', 'BPMN', 'ARIS', 'Обучение персонала', 'Обучение и развитие'],
#  ['DevOps', 'Scrum', 'CDP', 'CDL', 'CI', 'Agile', 'CI/CD'],
#  ['Финансовый анализ',
#   'Корпоративные финансы',
#   'МСФО',
#   'Финансовая отчетность',
#   'Консолидация финансовой отчетности',
#   'Оценка рисков'],
#  None,
#  ['Грамотная речь', 'HTML', 'Грамотность', 'Креативность', 'Гибкость'],
#  ['Figma', 'Работа в команде', 'UX', 'Adobe Photoshop', 'UI'],
#  None,
#  None,
#  None,
#  ['ООП', 'SQL', 'Java', 'Qt', 'Английский язык'],
#  None,
#  ['Информационные технологии',
#   'Администрирование',
#   'Автоматизированное рабочее место (АРМ)',
#   'АСУ'],
#  ['Spring Framework',
#   'Git',
#   'Apache Maven',
#   'Java',
#   'PostgreSQL',
#   'Openshift',
#   'Микросервисы'],
#  ['Финансовое моделирование',
#   'Корпоративные финансы',
#   'Анализ рисков',
#   'Инвестиционный анализ',
#   'Финансовый анализ'],
#  ['Python', 'Pandas', 'Linux', 'Numpy', 'SQL', 'ML', 'Deep Learning'],
#  None,
#  None,
#  ['JavaScript',
#   'React',
#   'Redux',
#   'TDD',
#   'REST API',
#   'React/Redux',
#   'React Native'],
#  ['Teradata',
#   'SQL',
#   'Python',
#   'Анализ данных',
#   'MS SQL',
#   'Навыки презентации',
#   'Аналитика',
#   'Qlik View',
#   'PowerPoint',
#   'BI',
#   'ORACLE',
#   'Sas',
#   'Agile',
#   'Hive'],
#  ['Python', 'SQL', 'Анализ данных', 'Аналитическое мышление'],
#  None,
#  None,
#  None,
#  ['SQL', 'Java', 'Spring Framework', 'PostgreSQL', 'Git'],
#  ['Управление проектами',
#   'Руководство коллективом',
#   'Java',
#   'Hibernate ORM',
#   'OpenShift'],
#  ['Английский язык',
#   'Функциональное тестирование',
#   'Android',
#   'Тестирование',
#   'iOS'],
#  ['Python', 'Hadoop', 'Atlassian Jira', 'Hive', 'SQL'],
#  ['SQL', 'Atlassian Jira', 'Kafka', 'PostgreSQL', 'Java'],
#  None,
#  None,
#  None,
#  ['Atlassian Jira', 'Atlassian Confluence', 'XML', 'Redmine', 'UML', 'JSON'],
#  ['JavaScript', 'Redux', 'Git', 'React', 'Node.js'],
#  None,
#  ['Деловая переписка',
#   'Деловое общение',
#   'Развитие продаж',
#   'Деловая коммуникация',
#   'Заключение договоров',
#   'Продажа кредитных продуктов',
#   'Активные продажи'],
#  None,
#  None,
#  ['SQL',
#   'Python',
#   'Математическая статистика',
#   'Математический анализ',
#   'MS PowerPoint'],
#  ['SQL', 'Teradata', 'Python'],
#  ['Python', 'Английский язык', 'Numpy', 'SQL', 'Linux'],
#  ['Анализ данных', 'Spark', 'SQL'],
#  None,
#  None,
#  ['Postman', 'Atlassian Jira', 'SQL', 'REST', 'PostgreSQL'],
#  ['Git', 'Linux', 'Docker', 'Python', 'Kubernetes'],
#  ['JavaScript', 'React', 'Redux', 'Git', 'TypeScript'],
#  None,
#  ['UML', 'Atlassian Jira', 'SQL', 'Atlassian Confluence', 'Системный анализ'],
#  ['SQL', 'Python', 'Java', 'Go', 'Docker'],
#  ['BPMN',
#   'UML',
#   'ARIS',
#   'Техническая документация',
#   'Jira',
#   'Confluence',
#   'Анализ требований'],
#  ['UML', 'SQL', 'REST', 'Java', 'PostgreSQL'],
#  ['Java',
#   'Spring Framework',
#   'Hibernate ORM',
#   'Java SE',
#   'Kubernetes',
#   'OpenShift',
#   'react'],
#  ['Активные продажи', 'Холодные продажи'],
#  None,
#  None,
#  ['SQL', 'PostgreSQL', 'ETL', 'ORACLE', 'Agile Project Management'],
#  ['Atlassian Confluence', 'Atlassian Jira', 'BPMN', 'MS Visio', 'SQL'],
#  ['Java', 'Java EE', 'REST', 'ООП', 'Java SE'],
#  ['React', 'React/Redux', 'TypeScript'],
#  None,
#  None,
#  ['Objective-C', 'Swift', 'iOS', 'Xcode', 'ООП'],
#  None,
#  ['Python', 'Git', 'SQL', 'QA'],
#  None,
#  ['Java',
#   'Spring Framework',
#   'PostgreSQL',
#   'Apache Maven',
#   'SQL',
#   'openshift'],
#  None,
#  ['BPMN',
#   'UML',
#   'XML',
#   'SQL',
#   'Xsd',
#   'JSON',
#   'REST',
#   'postman',
#   'Системный анализ',
#   'SOAP UI',
#   'Анализ требований'],
#  ['Java', 'Java SE', 'Spring Boot', 'Kafka', 'Maven', 'Docker', 'ООП'],
#  ['Bitbucket', 'CI', 'HTML/CSS', 'Confluence', 'React', 'Typescript'],
#  ['Spring Framework', 'SQL', 'Hibernate ORM', 'Java', 'REST'],
#  None,
#  None,
#  None,
#  None,
#  ['SAP ERP', 'ABAP', 'SAP FI', 'VBA', 'ООП'],
#  None,
#  None,
#  ['SQL',
#   'Обучение и развитие',
#   'Виды страхования',
#   'Ориентация на результат',
#   'Умение принимать решения'],
#  None,
#  ['Python', 'MongoDB', 'SQL', 'JavaScript', 'Git'],
#  None,
#  ['Elasticsearch', 'Python', 'Spark', 'Hadoop', 'Java'],
#  ['МСФО', 'ДипИФР', 'MS Excel'],
#  ['UML', 'SQL', 'Atlassian Jira', 'BPMN', 'XML'],
#  None,
#  ['Python', 'NLP', 'Machine Learning', 'PyTorch', 'SQL'],
#  ['Python',
#   'Linux',
#   'STL',
#   'TCP/IP',
#   'С++',
#   'Алгоритмы',
#   'Многопоточное программирование',
#   'C++',
#   'Структуры данных'],
#  ['Python',
#   'SQL',
#   'Linux',
#   'Английский язык',
#   'Numpy',
#   'Pandas',
#   'Математический анализ',
#   'Машинное обучение'],
#  ['Java', 'Git', 'SQL', 'Intellij IDEA', 'Atlassian Jira'],
#  ['Деловая переписка',
#   'Деловое общение',
#   'Развитие продаж',
#   'Деловая коммуникация',
#   'Заключение договоров',
#   'B2C продажи',
#   'Активные продажи'],
#  ['JavaScript', 'CSS', 'Redux', 'Node.js', 'React'],
#  ['JavaScript', 'Git', 'Redux', 'React', 'TypeScript'],
#  ['ИТ-аналитика',
#   'Бэк офис',
#   'Бизнес-аналитика',
#   'Управленческий анализ',
#   'Оптимизация бизнес процессов'],
#  ['Python', 'Docker', 'Atlassian Jira', 'Jenkins', 'MS PowerPoint'],
#  None,
#  None,
#  None,
#  ['Git', 'JavaScript', 'Node.js', 'Redux', 'React'],
#  None,
#  None,
#  ['Java'],
#  ['Java', 'SQL', 'REST API'],
#  None,
#  ['Atlassian Jira', 'Atlassian Confluence', 'SQL'],
#  ['Управление проектами',
#   'Обучение персонала',
#   'Agile Project Management',
#   'Hadoop',
#   'Greenplum',
#   'ETL',
#   'DataQuality',
#   'Campaign Management'],
#  ['JavaScript', 'Git', 'React', 'SQL', 'Docker', 'Redux'],
#  ['Проведение презентаций',
#   'Поиск и привлечение клиентов',
#   'Холодные продажи',
#   'Прямые продажи'],
#  ['Oracle Pl/SQL', 'SQL'],
#  None,
#  None,
#  ['JavaScript', 'Node.js', 'Docker', 'React'],
#  ['UML', 'BPMN', 'XML', 'SQL', 'REST', 'SOAP', 'Xsd', 'Архитектура'],
#  ['Java',
#   'Spring Framework',
#   'Hibernate',
#   'Oracle CRM',
#   'OpenShift',
#   'PostgreSQL',
#   'Hibernate ORM',
#   'SQL'],
#  None,
#  ['Python', 'SQL', 'Big Data', 'Spark', 'Базы данных'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Python', 'PyTorch', 'TensorFlow', 'Transformers', 'NLP/PLP'],
#  ['Kubernetes', 'Java', 'Kafka', 'Jenkins', 'Docker'],
#  ['SQL', 'Python', 'Java', 'Git', 'Spring Framework'],
#  ['Git', 'Spring Framework', 'Java', 'PostgreSQL', 'Jenkins'],
#  None,
#  ['Docker',
#   'Проведение семинаров',
#   'Техническая документация',
#   'HTTP',
#   'Architecture'],
#  ['Git', 'Spring Framework', 'Java', 'PostgreSQL', 'Jenkins'],
#  ['Python', 'SQL', 'Ориентация на результат', 'C++', 'Системное мышление'],
#  ['Linux', 'Python', 'Git', 'OpenCV', 'Bash'],
#  ['Linux', 'SQL', 'Bash', 'Ansible', 'IBM'],
#  ['OpenStack',
#   'Деловое общение',
#   'Обучение и развитие',
#   'Ориентация на результат',
#   'Подготовка отчетов',
#   'Confluence',
#   'Linux'],
#  ['Git', 'Java', 'Spring Framework', 'Jenkins', 'SQL'],
#  ['Деловая переписка',
#   'Финансовый анализ',
#   'Деловое общение',
#   'Поиск и привлечение клиентов',
#   'Заключение договоров'],
#  ['Python', 'Hadoop', 'Spark', 'SQL', 'Docker'],
#  None,
#  None,
#  ['Python', 'Flask', 'JavaScript', 'Docker', 'SQLAlchemy', 'React'],
#  ['Linux',
#   'Git',
#   'ORACLE',
#   'PostgreSQL',
#   'Kubernetes',
#   'Docker',
#   'Jenkins',
#   'Ansible',
#   'Bash'],
#  None,
#  None,
#  ['Python', 'Hadoop', 'SQL', 'Spark', 'Big Data'],
#  None,
#  ['SQL', 'Java', 'Linux', 'Тестирование'],
#  ['Jenkins', 'OpenShift', 'Корпоративная этика', 'Bitbucket', 'CI'],
#  ['SQL', 'XML', 'kafka', 'JSON API', 'REST', 'Анализ данных'],
#  None,
#  ['React', 'JavaScript', 'TypeScript', 'Node.js'],
#  ['Управление проектами',
#   'Jenkins',
#   'Деловая коммуникация',
#   'Kubernetes',
#   'DevOps'],
#  ['SQL', 'Python', 'Hadoop', 'Spark', 'Hive'],
#  ['Java',
#   'Spring Framework',
#   'Maven',
#   'Gradle',
#   'SOLID',
#   'JUnit',
#   'REST',
#   'ClickHouse',
#   'PostgreSQL',
#   'Kafka',
#   'Flink',
#   'Agile',
#   'Git',
#   'Linux'],
#  ['JavaScript', 'Git', 'Redux', 'Node.js', 'React'],
#  None,
#  ['UML', 'SQL', 'Atlassian Jira', 'BPMN', 'Atlassian Confluence'],
#  ['SQL',
#   'Olap (online analytical processing)',
#   'CRM',
#   'Работа с большим объемом информации',
#   'Бизнес-анализ'],
#  None,
#  ['Составление договоров',
#   'Сопровождение сделок',
#   'Английский язык',
#   'Договорная работа',
#   'Корпоративное право'],
#  None,
#  ['Английский язык',
#   'Грамотная речь',
#   'Деловая коммуникация',
#   'Работа с большим объемом информации',
#   'Административная поддержка руководителя',
#   'Контроль исполнения решений',
#   'Работа в режиме многозадачности',
#   'Грамотная устная и письменная речь',
#   'Управление временем',
#   'Стрессоустойчивость'],
#  ['Английский язык', 'Информационная безопасность', 'Управление рисками'],
#  None,
#  None,
#  None,
#  None,
#  ['Atlassian Confluence',
#   'SQL',
#   'Atlassian Jira',
#   'Системный анализ',
#   'BPMN',
#   'API',
#   'UML',
#   'Jira'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['JavaScript', 'Git', 'Redux', 'React', 'TypeScript'],
#  None,
#  ['Проведение презентаций',
#   'Поиск и привлечение клиентов',
#   'Холодные продажи',
#   'Прямые продажи'],
#  ['Figma',
#   'UX',
#   'Дизайн интерфейсов',
#   'Разработка нового продукта',
#   'Навыки презентации'],
#  None,
#  None,
#  ['SQL', 'Системный анализ', 'XML', 'JSON API', 'Hadoop', 'greenplum'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['MS PowerPoint', 'AI', 'Консалтинг'],
#  None,
#  ['Swift', 'ООП', 'iOS'],
#  None,
#  ['Java', 'Spring Framework', 'Kotlin', 'Apache Kafka', 'SQL'],
#  None,
#  ['SAP ERP', 'ООП', 'ABAP', 'SAP FI', 'SAP MM'],
#  ['Git', 'JavaScript', 'Управление проектами', 'Английский язык', 'react'],
#  ['Git', 'JavaScript', 'Node.js', 'React', 'Redux'],
#  None,
#  ['Python', 'PostgreSQL', 'Django Framework', 'Docker'],
#  None,
#  ['Linux', 'C++', 'STL', 'C/C++', 'Английский язык'],
#  ['Spark',
#   'SQL',
#   'Базы данных',
#   'Python',
#   'Machine Learning',
#   'Big Data',
#   'Математическая статистика',
#   'Pandas',
#   'Теория вероятностей',
#   'Numpy',
#   'Hadoop',
#   'Data Science'],
#  ['Анализ рынка',
#   'Аналитическое мышление',
#   'MS PowerPoint',
#   'Исследования рынка',
#   'Умение принимать решения'],
#  ['JavaScript', 'Redux', 'React', 'Git', 'TypeScript'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Xcode',
#   'Swift',
#   'iOS',
#   'Objective-C',
#   'REST API',
#   'мобильная разработка',
#   'ViewController'],
#  ['Git', 'Java', 'Spring Framework', 'Hadoop', 'SQL'],
#  ['JavaScript', 'Ориентация на результат', 'Гибкость', 'JS'],
#  None,
#  ['Git',
#   'Java',
#   'ООП',
#   'Linux',
#   'JVM',
#   'OpenShift',
#   'Spring Framework',
#   'Kafka',
#   'Spring Boot'],
#  ['Git',
#   'ООП',
#   'Оперативный поиск информации в сети Интернет',
#   'SOLID',
#   'MS Paint'],
#  ['Python', 'Git', 'Linux', 'Docker', 'Jenkins'],
#  None,
#  None,
#  None,
#  ['Java', 'Spring Framework', 'Git', 'Jenkins', 'SQL'],
#  ['Активные продажи',
#   'Проведение презентаций',
#   'Привлечение клиентов',
#   'Навыки продаж'],
#  ['Деловая коммуникация',
#   'Обучение и развитие',
#   'Управление временем',
#   'Выявление потребностей в обучении',
#   'Мониторинг'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Linux',
#   'Cоциальная реклама',
#   'Опытный пользователь ПК',
#   'Адаптация рекламных роликов',
#   'Работа с банками'],
#  ['кампейн', 'x-sell', 'CVM-стратегия', 'cross-sell', 'campaign'],
#  ['SQL', 'Обучение и развитие', 'MS SQL', 'Grafana', 'Проведение семинаров'],
#  ['SQL', 'XML', 'JSON API', 'UML', 'Android'],
#  ['Git', 'Java', 'SQL', 'CSS', 'HTML'],
#  None,
#  ['Git', 'JavaScript', 'Node.js', 'React', 'PostgreSQL'],
#  ['XML', 'UML', 'BPMN', 'SQL', 'Git', 'Системный анализ'],
#  None,
#  ['Анализ рисков',
#   'Моделирование бизнес процессов',
#   'Оценка рисков',
#   'MS PowerPoint',
#   'Аналитическое мышление'],
#  None,
#  ['Oracle Pl/SQL',
#   'SQL',
#   'ORACLE',
#   'XML',
#   'Atlassian Jira',
#   'сопровождение АС'],
#  None,
#  ['UX',
#   'Adobe Illustrator',
#   'UI',
#   'Проектирование пользовательских интерфейсов',
#   'Axure RP'],
#  None,
#  None,
#  None,
#  ['Java', 'Spring Framework', 'Hibernate ORM', 'REST'],
#  ['Python',
#   'SQL',
#   'Atlassian Jira',
#   'Английский язык',
#   'Atlassian Confluence'],
#  None,
#  None,
#  None,
#  None,
#  ['Git', 'Atlassian Jira', 'Agile', 'Jira', 'React/Redux'],
#  ['Windows Os', 'Творческое мышление', 'Гибкость', 'MS Paint', 'Turbo Pascal'],
#  ['Kotlin', 'Java', 'Git', 'Android', 'ООП'],
#  ['SAP', 'ООП', 'C#', 'МСФО', 'MS PowerPoint'],
#  ['Архитектура', 'Разработка концепции', 'Настройка сетевых подключений'],
#  ['Python', 'ML', 'HighLoad', 'C++', 'ElasticSearch'],
#  ['Jenkins',
#   'ansible',
#   'Bash',
#   'Zabbix',
#   'grafana',
#   'Администрирование серверов Linux',
#   'Linux',
#   'Docker',
#   'ELK',
#   'Мониторинг'],
#  ['OpenShift', 'Jenkins', 'Bitbucket', 'CI/СD', 'Ansible', 'Kubernetes'],
#  ['UML', 'BPMN', 'Системный анализ', 'Atlassian Jira', 'SQL'],
#  ['Python',
#   'Git',
#   'SQL',
#   'Django Framework',
#   'PostgreSQL',
#   'Django',
#   'PyTest',
#   'Flask',
#   'JS',
#   'RabbitMQ',
#   'Rest API',
#   'IBM MQ',
#   'Kafka'],
#  ['Git', 'Material UI', 'Jira', 'React/Redux', 'WebSockets'],
#  ['Python', 'Bash', 'Ansible', 'PostgreSQL', 'Linux'],
#  None,
#  None,
#  None,
#  ['Java', 'SQL', 'DevOps', 'Jira', 'Confluence', 'PostgreSQL', 'ORACLE'],
#  None,
#  ['Python', 'SQL', 'Git', 'JavaScript', 'Docker'],
#  ['Python',
#   'SQL',
#   'Анализ данных',
#   'ML',
#   'pandas',
#   'A/B тесты',
#   'Ad Hoc Analysis'],
#  ['UML', 'Kubernetes', 'MongoDB', 'PostgreSQL', 'Kafka', 'Terraform'],
#  ['Spring Framework', 'Git', 'Java', 'Apache Maven', 'PostgreSQL'],
#  ['JavaScript', 'Git', 'React', 'Redux', 'TypeScript'],
#  ['Git', 'Java', 'Apache Maven', 'SQL', 'Jenkins'],
#  None,
#  None,
#  ['Atlassian Jira', 'SQL', 'Linux', 'Системное мышление', 'Многозадачность'],
#  None,
#  None,
#  ['Управление проектами',
#   'Scrum',
#   'Agile Project Management',
#   'Atlassian Jira'],
#  ['Деловая переписка',
#   'Развитие продаж',
#   'Деловая коммуникация',
#   'Заключение договоров',
#   'B2C продажи',
#   'Активные продажи'],
#  ['SAP', 'SAP HANA', 'JS', 'UI5', 'Fiori', 'OData', 'Frontend'],
#  ['Python', 'Docker', 'Adobe Photoshop', 'Django Framework', 'Redis'],
#  None,
#  ['XML', 'SQL', 'UML', 'Atlassian Jira', 'Atlassian Confluence'],
#  None,
#  None,
#  ['JavaScript', 'CSS', 'HTML', 'TypeScript'],
#  ['Python', 'Linux', 'JavaScript', 'Git', 'Английский язык'],
#  None,
#  ['Kotlin', 'SQLite', 'Android SDK', 'Java', 'Android'],
#  ['UML', 'SQL', 'BPMN', 'Atlassian Confluence', 'Atlassian Jira'],
#  None,
#  None,
#  ['SQL', 'QlikView', 'Qlik Sense', 'Бизнес-анализ', 'Анализ данных'],
#  ['Работа в команде',
#   'Умение работать в команде',
#   'Умение работать в коллективе',
#   'Способность обучать других',
#   'Материальная ответственность'],
#  ['ORACLE', 'MongoDB', 'PostgreSQL'],
#  ['Spring Framework', 'Apache Maven', 'Hibernate ORM', 'Git', 'Java'],
#  None,
#  None,
#  None,
#  ['Python',
#   'SQL',
#   'Обучение персонала',
#   'Обучение и развитие',
#   'Data Science'],
#  ['PostgreSQL', 'Python', 'MS SQL', 'SQL', 'Linux'],
#  ['Agile Project Management',
#   'Управление проектами',
#   'Работа в команде',
#   'Деловая коммуникация',
#   'Английский язык',
#   'Jira',
#   'Miro',
#   'Agile',
#   'Trello',
#   'Разработка стратегии продвижения продуктов'],
#  None,
#  None,
#  ['Git', 'Linux', 'Jenkins', 'Bash', 'SQL'],
#  None,
#  ['Oracle Pl/SQL',
#   'Разработка инструкций',
#   'SQL',
#   'MS PowerPoint',
#   'База данных: Oracle'],
#  ['JavaScript', 'Git', 'HTML5', 'CSS3', 'Redux'],
#  None,
#  None,
#  None,
#  ['Unix', 'Unix Shell Scripts', 'Bash', 'Linux', 'TCP/IP', 'Sybase'],
#  ['SQL', 'Java', 'SCALA', 'Oracle Pl/SQL', 'Hadoop'],
#  ['Git', 'PostgreSQL', 'Java', 'Jenkins', 'Docker'],
#  None,
#  ['Hadoop', 'SQL', 'Python'],
#  ['Atlassian Jira', 'UML', 'XML', 'SQL', 'Atlassian Confluence'],
#  ['Spring Framework',
#   'Оптимизация бизнес-процессов',
#   'Java',
#   'Adobe Dreamweaver',
#   'Java SE',
#   'SQL',
#   'PostgreSQL',
#   'Руководство коллективом'],
#  None,
#  None,
#  None,
#  ['Linux', 'MS SQL Server', 'SQL', 'PostgreSQL', 'MS SQL'],
#  ['UML', 'SQL', 'BPMN', 'Atlassian Jira', 'Системный анализ'],
#  ['СУБД',
#   'Cистемы управления базами данных',
#   'SQL',
#   'Базы данных',
#   'OpenShift',
#   'Linux',
#   'Администрирование серверов Linux'],
#  None,
#  ['Деловая переписка',
#   'Деловое общение',
#   'Развитие продаж',
#   'Деловая коммуникация',
#   'Заключение договоров',
#   'B2C продажи',
#   'Активные продажи'],
#  None,
#  None,
#  None,
#  None,
#  ['Jenkins', 'Git', 'Ansible', 'Linux', 'Kubernetes'],
#  None,
#  ['Atlassian Jira',
#   'Atlassian Confluence',
#   'Java',
#   'Apache Kafka',
#   'SQL',
#   'Аналитика'],
#  None,
#  None,
#  ['React/Redux', 'TypeScript', 'MobX', 'Frontend', 'REST'],
#  ['Objective-C', 'iOS', 'Swift'],
#  ['Python', 'Git', 'SQL', 'Spark', 'PostgreSQL'],
#  ['Python', 'Git', 'Linux', 'Atlassian Jira', 'Jenkins'],
#  ['BPMN', 'Английский язык', 'UML', 'SQL', 'REST'],
#  ['Управление проектами',
#   'Atlassian Confluence',
#   'MS Project',
#   'Agile Project Management',
#   'Atlassian Jira'],
#  None,
#  ['Swift', 'Adobe Photoshop', 'ООП', 'iOS', 'C++'],
#  ['SCALA', 'SQL', 'Bash', 'Java', 'Hadoop', 'Высшее образование'],
#  ['Git', 'Kafka', 'Jenkins', 'XML', 'Тестирование', 'Java'],
#  None,
#  ['Функциональное тестирование',
#   'Английский язык',
#   'Atlassian Jira',
#   'Тестирование',
#   'Проведение тестирований'],
#  None,
#  None,
#  ['Docker', 'Работа с базами данных', 'Big Data', 'Управление временем'],
#  ['BPMN', 'UML', 'SQL', 'Git', 'Spring Framework'],
#  ['SQL',
#   'Базы данных',
#   'MS SQL',
#   'Cистемы управления базами данных',
#   'Работа с базами данных'],
#  None,
#  ['Git', 'SQL', 'Intellij IDEA', 'Java', 'Spring Framework'],
#  ['Big Data', 'SQL', 'Python', 'Linux', 'Hadoop'],
#  None,
#  ['SQL', 'Linux', 'Java', 'Git', 'Английский язык'],
#  ['Python', 'Git', 'Java', 'SQL', 'SCALA'],
#  ['Работа в команде',
#   'Грамотная речь',
#   'Работа с большим объемом информации',
#   'Грамотность'],
#  ['Python', 'Hadoop', 'SQL', 'SCALA', 'Spark'],
#  None,
#  None,
#  ['Python', 'Django Framework', 'SQL', 'XML', 'JSON API'],
#  ['Python', 'Hadoop', 'SQL', 'Spark', 'SCALA'],
#  None,
#  ['Data Scientist',
#   'TensorFlow',
#   'Pandas',
#   'Python',
#   'PyData',
#   'Greeplum',
#   'Hadoop',
#   'SCALA',
#   'SQL',
#   'DS'],
#  ['Ansible', 'Docker', 'Linux', 'DevOps', 'Анализ данных'],
#  None,
#  ['SQL',
#   'Базы данных',
#   'MS SQL',
#   'Cистемы управления базами данных',
#   'Работа с базами данных'],
#  ['Jenkins', 'Unix', 'Linux', 'Bash', 'Git'],
#  ['Управление проектами',
#   'Обучение и развитие',
#   'Управление процессами',
#   'Стратегическое мышление',
#   'Лидерство',
#   'Java',
#   'JavaScript',
#   'react',
#   'Spring Framework'],
#  ['Atlassian Jira',
#   'SQL',
#   'Atlassian Confluence',
#   'XML',
#   'Бизнес-анализ',
#   'Системное мышление',
#   'Системный анализ',
#   'BPMN',
#   'UML',
#   'REST',
#   'Работа с базами данных',
#   'Системная интеграция',
#   'Xsd',
#   'Коммуникабельность, стрессоустойчивость'],
#  None,
#  ['ITIL', 'ITSM'],
#  None,
#  None,
#  ['REST', 'JSON API', 'XML', 'Postman', 'Системный анализ', 'gRPC'],
#  ['iOS', 'Анализ кода', 'Java', 'Python', 'Android'],
#  None,
#  ['Atlassian Jira',
#   'Atlassian Confluence',
#   'Управление временем',
#   'Критическое мышление',
#   'Jira',
#   'Mac Os',
#   'Objective-C',
#   'iOS'],
#  ['Java', 'Docker', 'ООП', 'Kafka', 'Системное мышление'],
#  ['Git', 'Linux', 'Jenkins', 'Python', 'Jmeter'],
#  None,
#  ['Git', 'Python', 'Java', 'Jenkins', 'C#'],
#  None,
#  ['Splunk', 'OpenShift', 'Atlassian Jira', 'Организаторские навыки', 'ITSM'],
#  ['Работа в команде',
#   'Atlassian Jira',
#   'Atlassian Confluence',
#   'Деловая коммуникация',
#   'Управление офисами компании'],
#  None,
#  None,
#  None,
#  None,
#  ['Java', 'Spring Framework', 'Apache Kafka', 'SQL', 'CI/CD', 'Kubernetes'],
#  None,
#  ['Hibernate ORM', 'SQL', 'Apache Maven', 'ООП'],
#  ['Java',
#   'Atlassian Jira',
#   'Atlassian Confluence',
#   'Postman',
#   'API',
#   'charles',
#   'fiddler'],
#  None,
#  ['DWH', 'Hadoop', 'Spark', 'Greenplum'],
#  None,
#  ['Python',
#   'Тестирование пользовательского интерфейса',
#   'Pytest',
#   'Selenium',
#   'Behave',
#   'Автоматизация тестирования',
#   'Автоматизированное тестирование'],
#  ['Fiddler', 'MQ', 'Jenkins', 'XML', 'HTTP'],
#  ['Hadoop', 'SQL', 'Hive', 'Spark', 'Python'],
#  ['Hadoop', 'NoSQL', 'Администрирование', 'Kafka'],
#  ['devops',
#   'Hadoop',
#   'Spark',
#   'Kafka',
#   'Cloudera',
#   'Hive',
#   'HDFS',
#   'Linux',
#   'Hortonworks'],
#  None,
#  None,
#  None,
#  ['SQL', 'JUnit', 'Java', 'REST'],
#  None,
#  None,
#  ['Linux', 'Bash', 'Zabbix', 'CentOS', 'SQL'],
#  None,
#  ['Java',
#   'Apache Maven',
#   'Git',
#   'ООП',
#   'Hibernate ORM',
#   'Kafka',
#   'PostgreSQL'],
#  ['Splunk',
#   'Организаторские навыки',
#   'OpenShift',
#   'Умение принимать решения',
#   'Grafana'],
#  None,
#  ['SAP BW', 'SAP HANA', 'ABAP', 'SAP BI'],
#  None,
#  ['Spring Framework',
#   'PostgreSQL',
#   'Java',
#   'Jenkins',
#   'Git',
#   'OpenShift',
#   'Hibernate',
#   'Kafka'],
#  ['JavaScript', 'Redux', 'TypeScript', 'React'],
#  ['Python', 'SQL', 'Git', 'Docker', 'JavaScript'],
#  ['Python', 'hadoop', 'Big Data', 'Spark', 'airflow', 'ETL'],
#  ['Python', 'Spark', 'SQL', 'SCALA', 'Hadoop'],
#  None,
#  ['Python', 'Flask', 'JavaScript', 'Docker', 'SQLAlchemy', 'React'],
#  None,
#  ['Kafka', 'Docker', 'Kubernetes', 'OpenShift', 'Atlassian Jira'],
#  ['Linux', 'Spring Framework', 'Java', 'Обучение и развитие', 'SQL'],
#  None,
#  None,
#  ['XML', 'Управление проектами', 'SOAP', 'Ajax', 'HTML', 'интеграции'],
#  None,
#  None,
#  None,
#  None,
#  ['MS SQL', 'ORACLE', 'ITIL', 'ITSM', 'WAS', 'LDAP'],
#  None,
#  ['SQL', 'Java', 'Spring Framework', 'PostgreSQL', 'Git'],
#  ['SQL', 'Atlassian Jira', 'REST', 'Системный анализ', 'UML', 'CMDB'],
#  ['Python', 'PostgreSQL', 'Go'],
#  None,
#  None,
#  ['Git', 'Java', 'Kotlin', 'Linux', 'Английский язык'],
#  None,
#  None,
#  None,
#  ['Информационная безопасность',
#   'IDM',
#   'IAM',
#   'SSO',
#   'PAM',
#   'OpenID Connect',
#   'OAuth',
#   'Управление доступом'],
#  ['Java',
#   'Hibernate ORM',
#   'PostgreSQL',
#   'Spring Framework',
#   'REST',
#   'Kafka',
#   'Apache Maven',
#   'Gradle',
#   'Рефакторинг кода'],
#  None,
#  ['Git', 'SQL', 'Linux', 'Java', 'Kotlin'],
#  ['Python', 'PostgreSQL', 'Bash', 'Groovy', 'Zabbix', 'Jenkins', 'Linux'],
#  ['Python', 'Hadoop', 'Hive', 'Spark', 'Atlassian Jira'],
#  ['Системный анализ', 'BPMN', 'SQL', 'Бизнес-анализ'],
#  ['Git', 'SQL', 'PostgreSQL', 'Java', 'Linux'],
#  None,
#  None,
#  None,
#  ['SQL',
#   'Английский язык',
#   'Базы данных',
#   'Lua',
#   'Оперативный поиск информации в сети Интернет'],
#  None,
#  ['Oracle Pl/SQL',
#   'SQL',
#   'VBA',
#   'Работа с большим объемом информации',
#   'ORACLE'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Teradata', 'SQL', 'Hadoop', 'Spark', 'Hive', 'SCALA'],
#  None,
#  ['Git', 'SQL', 'Linux', 'Atlassian Jira', 'Docker'],
#  ['JavaScript', 'Node.js'],
#  None,
#  ['Java',
#   'Spring Framework',
#   'PostgreSQL',
#   'ООП',
#   'Hibernate',
#   'Apache Kafka',
#   'Gitlab'],
#  None,
#  None,
#  None,
#  None,
#  ['Big Data', 'SQL', 'ETL', 'Системный анализ', 'DWH'],
#  None,
#  None,
#  None,
#  ['Информационная безопасность',
#   'Английский язык',
#   'Java',
#   'Kubernetes',
#   'Linux'],
#  None,
#  None,
#  None,
#  ['Docker', 'Управление проектами', 'Git', 'Java', 'Go'],
#  None,
#  None,
#  ['Python',
#   'Java',
#   'SQL',
#   'Нагрузочное тестирование',
#   'Организация мероприятий'],
#  None,
#  ['SCALA',
#   'Python',
#   'kafka',
#   'Spark',
#   'GreenPlum',
#   'Big Data',
#   'Git',
#   'Spark Streaming',
#   'Hadoop',
#   'Data Engineer',
#   'Engineer'],
#  ['Управление проектами',
#   'Работа в команде',
#   'Организаторские навыки',
#   'Agile Project Management',
#   'Деловая коммуникация'],
#  ['Spring Framework', 'Java'],
#  ['Python', 'Big Data', 'SQL', 'MongoDB', 'Анализ данных', 'hadoop', 'Spark'],
#  None,
#  ['Java', 'OpenShift', 'Kafka', 'Умение принимать решения', 'Java Core'],
#  ['Тестирование', 'REST', 'API', 'Java'],
#  ['JavaScript', 'TypeScript', 'Git', 'React', 'Redux', 'Hooks', 'Thunk'],
#  ['Scrum', 'Atlassian Jira', 'Git', 'ООП', 'Agile Project Management', 'C++'],
#  ['JavaScript', 'Git', 'HTML', 'CSS', 'Atlassian Jira', 'ReactJS', 'Node.js'],
#  ['Spring Framework', 'Java', 'PostgreSQL'],
#  ['Atlassian Jira', 'UML', 'Atlassian Confluence', 'BPMN', 'SQL'],
#  None,
#  None,
#  None,
#  ['Ansible', 'Linux', 'Python', 'Bash', 'PostgreSQL'],
#  None,
#  ['TOGAF',
#   'Agile Project Management',
#   'MS PowerPoint',
#   'Деловая коммуникация',
#   'Kafka'],
#  ['Git', 'SCALA', 'PostgreSQL', 'Python', 'Hadoop'],
#  ['Java', 'Spring Framework', 'BPMN', 'JavaScript'],
#  None,
#  ['MS Access',
#   'Управление временем',
#   'Системное мышление',
#   'MS Paint',
#   'Добровольное медицинское страхование'],
#  ['Market Data', 'Бэк офис', 'Bloomberg', 'Diasoft', 'Фондовый рынок'],
#  None,
#  None,
#  ['Java',
#   'Android SDK',
#   'Kotlin',
#   'Android',
#   'Добровольное медицинское страхование'],
#  None,
#  None,
#  None,
#  ['Git',
#   'Python',
#   'Docker',
#   'Умение принимать решения',
#   'Kafka',
#   'управление проектом'],
#  None,
#  ['Ansible', 'Bash', 'Linux', 'Jenkins', 'Shell Scripting'],
#  None,
#  ['Java'],
#  ['Python', 'ML', 'Airflow', 'SQL'],
#  None,
#  ['Redux', 'React/Redux'],
#  None,
#  ['Git', 'Java', 'Python', 'Spring Framework', 'JavaScript'],
#  None,
#  None,
#  None,
#  None,
#  ['Spring Framework', 'Java', 'Hibernate ORM', 'Apache Maven', 'Git'],
#  ['Node.js', 'JavaScript', 'Docker', 'Linux', 'Kubernetes'],
#  None,
#  ['Git', 'Atlassian Jira', 'Agile Project Management', 'Scrum', 'Kanban'],
#  None,
#  None,
#  ['Работа с большим объемом информации',
#   'Бизнес-анализ',
#   'аналитика',
#   'ITSM',
#   'ITIL',
#   'Аудит',
#   'Отчетность'],
#  ['SQL', 'Atlassian Jira', 'Hadoop', 'MS SQL', 'Разработка ПО'],
#  ['UML',
#   'BPMN',
#   'Agile Project Management',
#   'Atlassian Jira',
#   'Atlassian Confluence'],
#  None,
#  ['Spring Framework', 'PostgreSQL', 'Hibernate ORM', 'Git', 'Docker'],
#  ['Java', 'Kotlin', 'Spring'],
#  ['Atlassian Jira', 'Atlassian Confluence', 'Figma', 'SQL', 'Python', 'CJM'],
#  ['Работа в команде',
#   'Управление проектами',
#   'Организаторские навыки',
#   'Обучение персонала',
#   'управление данными',
#   'Data Governance',
#   'качество данных'],
#  None,
#  ['Kotlin', 'Java', 'Git', 'Android SDK', 'Atlassian Jira'],
#  None,
#  ['Python', 'Atlassian Jira', 'Linux', 'Docker', 'C++'],
#  None,
#  None,
#  ['OpenShift', 'OpenStack', 'Docker', 'Kubernetes', 'TOGAF'],
#  ['Базы данных',
#   'Bash',
#   'Сопровождение ПО',
#   'CI/CD',
#   'SQL',
#   'Python',
#   'Jenkins'],
#  ['Atlassian Jira',
#   'Atlassian Confluence',
#   'UML',
#   'Аналитическое мышление',
#   'XML',
#   'Налоговое законодательство'],
#  None,
#  ['SQL', 'Linux', 'Python', 'PostgreSQL'],
#  ['Spring Framework',
#   'Java',
#   'SQL',
#   'ООП',
#   'Kubernetes',
#   'OpenShift',
#   'PG PL/SQL',
#   'Kafka',
#   'Agile',
#   'NoSQL',
#   'IMDG'],
#  ['Ansible', 'Linux', 'Python', 'SQL', 'Jenkins'],
#  None,
#  None,
#  ['Atlassian Jira', 'SQL', 'Linux', 'Системное мышление', 'Многозадачность'],
#  ['SCALA', 'Java', 'Spark', 'Hive', 'Big Data', 'Hadoop'],
#  None,
#  ['Unit Testing',
#   'Java',
#   'Hibernate ORM',
#   'Spring Framework',
#   'REST',
#   'OpenShift',
#   'JUnit',
#   'PostgreSQL',
#   'Spring',
#   'Gradle'],
#  None,
#  ['Python', 'Django Framework', 'Apache Kafka', 'PostgreSQL', 'Docker', 'Git'],
#  None,
#  ['Cassandra',
#   'Java',
#   'Управление проектами',
#   'Деловая коммуникация',
#   'Проведение презентаций'],
#  None,
#  None,
#  ['Bash', 'Grafana', 'Мониторинг', 'Zabbix', 'ELK', 'Linux'],
#  None,
#  ['Linux', 'Bash', 'Python', 'SQL', 'DevOps'],
#  None,
#  ['Figma', 'UX', 'UI', 'Adobe Photoshop', 'Principle'],
#  None,
#  ['JavaScript'],
#  None,
#  None,
#  None,
#  ['Hive', 'SCALA', 'Python', 'Git', 'Java', 'MS SQL'],
#  None,
#  ['SQL', 'UML', 'PostgreSQL', 'ORACLE', 'SOAP', 'Xsd', 'REST'],
#  None,
#  ['Java', 'Spring Framework'],
#  ['Linux', 'SQL', 'Jenkins', 'СУБД', 'Big Data', 'Python'],
#  None,
#  None,
#  ['SQL', 'REST', 'SOAP', 'Atlassian Jira'],
#  ['Git', 'PostgreSQL', 'Java', 'Liquibase', 'Jenkins'],
#  ['Git', 'PostgreSQL', 'SQL', 'OpenShift', 'Spring Framework', 'Java'],
#  ['SQL', 'XML', 'UML', 'BPMN', 'Системный анализ'],
#  None,
#  None,
#  None,
#  ['SAP HR', 'Agile', 'обучение сотрудников', 'Trello', 'Работа с банками'],
#  ['Node.js', 'REST', 'PostgreSQL', 'Docker', 'работа в офисе', 'Java'],
#  None,
#  ['SQL', 'Git', 'Linux', 'Kubernetes', 'Java'],
#  ['Big Data', 'SQL', 'ETL', 'DWH', 'Организаторские навыки'],
#  ['PostgreSQL',
#   'Git',
#   'Linux',
#   'ORACLE',
#   'ETL',
#   'Bash',
#   'Oracle Pl/SQL',
#   'CI\\CD',
#   'WildFly',
#   'Openshift',
#   'kubernetes'],
#  ['XML', 'SQL', 'Java', 'Функциональное тестирование', 'Тестирование'],
#  None,
#  None,
#  None,
#  None,
#  ['Подготовка презентаций',
#   'Аналитическое мышление',
#   'Навыки презентации',
#   'MS Access',
#   'Добровольное медицинское страхование'],
#  ['Git', 'Linux', 'Docker', 'Python', 'Kubernetes'],
#  None,
#  ['UML', 'XML', 'BPMN', 'Системный анализ', 'REST'],
#  ['Spring Framework', 'Java', 'Jenkins'],
#  ['Oracle Pl/SQL', 'Grafana', 'SQL', 'ORACLE', 'Работа с базами данных'],
#  None,
#  ['JavaScript', 'TypeScript', 'React', 'HTML5'],
#  ['Git',
#   'Jenkins',
#   'Java',
#   'JavaScript',
#   'Hibernate ORM',
#   'Spring Framework',
#   'Java EE',
#   'Java Core',
#   'Kotlin'],
#  ['SQL', 'Big Data', 'ETL', 'DWH', 'Teradata'],
#  ['UML',
#   'Разработка технических заданий',
#   'Управление проектами',
#   'Постановка задач разработчикам',
#   'Kafka'],
#  ['Hadoop', 'Spark', 'Big Data', 'GO', 'Golang'],
#  ['Git', 'Kotlin', 'Android', 'ООП', 'Android SDK', 'Coroutines', 'Jackson'],
#  None,
#  None,
#  ['Spring Framework', 'Hibernate ORM', 'PostgreSQL', 'Java', 'Apache Maven'],
#  None,
#  None,
#  ['UML',
#   'XML',
#   'BPMN',
#   'Системный анализ',
#   'Разработка технических заданий',
#   'JSON API'],
#  None,
#  None,
#  ['SQL', 'PostgreSQL', 'Python', 'Java', 'MySQL'],
#  ['Git', 'Python', 'Linux', 'Английский язык', 'Docker'],
#  None,
#  None,
#  ['Python',
#   'Ansible',
#   'Nginx',
#   'Docker',
#   'Bash',
#   'Jenkins',
#   'Unix',
#   'PostgreSQL',
#   'WebSphere',
#   'WildFly',
#   'Shell Scripting'],
#  ['ORACLE', 'Oracle CRM', 'Удаленная работа', 'Логика', 'Технолог'],
#  ['Управление проектами',
#   'Организаторские навыки',
#   'Agile Project Management',
#   'Atlassian Jira',
#   'Деловая коммуникация'],
#  ['Python', 'Java', 'Git', 'SQL', 'JavaScript'],
#  None,
#  None,
#  ['Python', 'NLP', 'Deep Learning', 'Linux', 'Docker'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Python', 'SQL', 'ООП', 'XML', 'Pandas'],
#  None,
#  ['Git', 'Redis', 'Docker', 'RabbitMQ', 'Go'],
#  ['Git', 'Python', 'Selenium', 'Jenkins', 'ООП'],
#  ['Python', 'Hadoop', 'Spark', 'Hive', 'SQL'],
#  None,
#  ['Java', 'Spring Framework', 'Java EE', 'SQL'],
#  ['Git', 'JavaScript', 'Node.js', 'TypeScript', 'React'],
#  ['SQL'],
#  ['Java',
#   'Git',
#   'SQL',
#   'Intellij IDEA',
#   'Allure',
#   'Jenkins',
#   'Postman',
#   'Spring'],
#  ['Python', 'OpenStack'],
#  ['Linux', 'Python', 'Bash', 'Английский язык', 'OpenShift', 'XML', 'JSON'],
#  None,
#  ['iOS', 'Android'],
#  None,
#  None,
#  None,
#  ['Git', 'Java', 'Spring Framework', 'Английский язык', 'SQL'],
#  None,
#  ['Git', 'PostgreSQL', 'Java', 'Python', 'SQL'],
#  None,
#  ['Git', 'Java', 'Kotlin', 'Информационная безопасность', 'Linux'],
#  None,
#  ['Ansible', 'Администрирование', 'Jenkins', 'CI'],
#  None,
#  None,
#  ['Linux',
#   'Bash',
#   'Jenkins',
#   'DevOps',
#   'Hadoop',
#   'Spark',
#   'Zabbix',
#   'OpenStack',
#   'Hive',
#   'Администрирование серверов Linux'],
#  ['SQL',
#   'Git',
#   'Java',
#   'REST',
#   'QA',
#   'API',
#   'PostgreSQL',
#   'Postman',
#   'Docker',
#   'Kafka'],
#  None,
#  None,
#  None,
#  ['Linux', 'Nginx', 'Ansible', 'Bash', 'Git'],
#  ['BPMN', 'XML', 'UML', 'SQL', 'SOAP'],
#  None,
#  ['Автоматизация процессов'],
#  ['SQL', 'Python', 'Git', 'JavaScript', 'Docker'],
#  None,
#  None,
#  ['Информационная безопасность',
#   'Деловая коммуникация',
#   'MS PowerPoint',
#   'Стратегическое мышление',
#   'MS Access'],
#  None,
#  ['Python',
#   'Spark',
#   'machine learning',
#   'Математическое моделирование',
#   'Математический анализ',
#   'ML',
#   'Проведение презентаций'],
#  ['Python', 'REST', 'UML', 'BPMN', 'Atlassian Jira', 'SQL', 'SOAP', 'Java'],
#  ['SQL', 'Big Data', 'ETL', 'Работа с базами данных', 'DWH'],
#  None,
#  ['Java',
#   'SQL',
#   'Apache Maven',
#   'Тестирование',
#   'Selenium',
#   'Cucumber',
#   'Автоматизированное тестирование',
#   'QA'],
#  None,
#  None,
#  ['Kafka', 'Archimate', 'UML', 'Architecture', 'Apache Kafka'],
#  None,
#  None,
#  None,
#  ['Big Data',
#   'Обучение и развитие',
#   'Администрирование',
#   'Управление временем',
#   'Страхование жизни'],
#  None,
#  None,
#  ['Bash', 'Linux', 'docker', 'Jenkins', 'ansible'],
#  ['Python', 'Git', 'Docker', 'Linux', 'Java'],
#  ['Java', 'Spring Framework'],
#  None,
#  ['UML', 'SQL', 'Java', 'BPMN', 'REST'],
#  None,
#  None,
#  ['SQL', 'Java', 'Atlassian Jira', 'ETL', 'Big Data'],
#  None,
#  None,
#  ['Java',
#   'Git',
#   'Spring',
#   'SQL',
#   'Apache Kafka',
#   'WildFly',
#   'Java SE',
#   'REST'],
#  ['JavaScript',
#   'CSS3',
#   'Python',
#   'TypeScript',
#   'Less',
#   'AngularJS',
#   'Vue',
#   'RxJS',
#   'webpack',
#   'ECMA'],
#  ['UML', 'BPMN', 'XML', 'REST', 'SOAP', 'Системный анализ'],
#  None,
#  None,
#  ['Data Scientist',
#   'NLU',
#   'pytorch',
#   'DS',
#   'Hadoop',
#   'Spark',
#   'NLP',
#   'Natural Language Processing'],
#  None,
#  ['Kotlin', 'Java', 'Android SDK', 'Git', 'Android'],
#  None,
#  ['TOGAF', 'Микросервисы', 'SOA', 'ESB', 'Cloud computing'],
#  ['Hadoop', 'Spark', 'SQL', 'Python', 'SCALA'],
#  None,
#  None,
#  ['SQL', 'OpenShift', 'Atlassian Jira', 'Apache kafka'],
#  None,
#  ['Docker', 'Ansible', 'Jenkins', 'OpenShift', 'Git'],
#  ['Git',
#   'Java',
#   'SQL',
#   'Jenkins',
#   'Apache Maven',
#   'Тестирование',
#   'Проведение тестирований',
#   'Selenium'],
#  ['PostgreSQL', 'MongoDB', 'Kubernetes'],
#  ['Docker',
#   'Ansible',
#   'Jenkins',
#   'Kubernetes',
#   'Atlassian Jira',
#   'Linux',
#   'DevOps',
#   'OpenShift'],
#  None,
#  ['Работа в команде',
#   'Работа в условиях многозадачности',
#   'Умение адаптироваться',
#   'Office',
#   'Умение работать в условиях многозадачности'],
#  ['Тестирование',
#   'Postman',
#   'QA',
#   'SQL',
#   'Проведение тестирований',
#   'Функциональное тестирование',
#   'Интеграционное тестирование',
#   'Регресcионное тестирование',
#   'DevTools'],
#  ['SQL', 'Java', 'Linux', 'SCALA', 'Hadoop'],
#  ['Spring Framework', 'Java', 'PostgreSQL', 'SQL', 'Hibernate ORM'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['SQL', 'Java', 'Linux', 'Тестирование'],
#  None,
#  None,
#  None,
#  None,
#  ['Python',
#   'SQL',
#   'Linux',
#   'Jenkins',
#   'OpenShift',
#   'DevOps',
#   'СУБД',
#   'Банковское ПО',
#   'MS SQL'],
#  None,
#  ['Git', 'SQL', 'Python', 'PostgreSQL', 'ORACLE'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Ansible', 'Jenkins', 'Kubernetes', 'Bash', 'Python'],
#  None,
#  None,
#  ['Git', 'Java', 'Spring Framework', 'Apache Maven', 'JUnit'],
#  ['Oracle Pl/SQL',
#   'SQL',
#   'Работа с большим объемом информации',
#   'Управление временем',
#   'Сбор и анализ информации'],
#  None,
#  None,
#  ['SQL',
#   'Внутренний контроль',
#   'C++',
#   'Анализ текущих финансовых показателей',
#   'Oracle DB'],
#  None,
#  None,
#  None,
#  ['Linux', 'Git', 'Jenkins', 'Java', 'Python'],
#  ['Java', 'Spark', 'hadoop', 'Big Data', 'SCALA'],
#  None,
#  None,
#  ['ALM', 'Python', 'Процентный риск'],
#  None,
#  None,
#  ['Atlassian Jira',
#   'SQL',
#   'Функциональное тестирование',
#   'Тестирование',
#   'Test case'],
#  ['Ansible', 'Linux', 'Python', 'Bash', 'RHEL'],
#  None,
#  ['Ansible',
#   'Git',
#   'Kubernetes',
#   'Bash',
#   'CI/CD',
#   'Jenkins',
#   'OpenShift',
#   'ELK',
#   'DevOps',
#   'Shell Scripting',
#   'Linux'],
#  ['Atlassian Jira', 'Git', 'Atlassian Confluence', 'SQL', 'Jenkins'],
#  ['Atlassian Jira',
#   'SQL',
#   'Atlassian Confluence',
#   'Постановка задач разработчикам',
#   'Управление проектами',
#   'REST',
#   'BPMN'],
#  None,
#  ['Hadoop', 'Greenplum', 'DWH'],
#  None,
#  None,
#  None,
#  ['Управление проектами',
#   'Английский язык',
#   'Деловая коммуникация',
#   'Управление бизнес процессами',
#   'Многозадачность'],
#  None,
#  None,
#  None,
#  ['Python', 'SQL', 'Hadoop', 'Machine Learning', 'Data Mining'],
#  None,
#  ['Linux', 'Git', 'Python', 'PostgreSQL', 'Docker'],
#  ['Git', 'Python', 'JavaScript', 'Allure', 'Jmeter', 'Java'],
#  None,
#  None,
#  ['Git', 'Atlassian Jira', 'XPath', 'Java', 'Scrum'],
#  None,
#  ['Jenkins', 'Git', 'Bash', 'Ansible', 'Docker', 'OpenShift', 'DevOps'],
#  ['Git', 'Java', 'Jenkins', 'Apache Maven', 'SQL'],
#  None,
#  ['Управление проектами',
#   'Управление рисками',
#   'Agile Project Management',
#   'Информационная безопасность',
#   'Анализ рисков'],
#  None,
#  ['SQL', 'SCALA', 'Java', 'Spark', 'Spring Framework'],
#  ['Linux', 'PostgreSQL', 'SQL', 'Python', 'Docker'],
#  None,
#  None,
#  None,
#  ['Hadoop', 'Kafka', 'Spark', 'Системный анализ', 'Kanban', 'TDD'],
#  ['Java', 'XML', 'SQL', 'Spring Framework', 'REST'],
#  ['Docker', 'Java', 'PostgreSQL'],
#  None,
#  None,
#  None,
#  None,
#  ['Python', 'API', 'PostgreSQL'],
#  ['iOS', 'Objective-C', 'Swift'],
#  ['Git', 'Java', 'Hibernate ORM', 'Spring Framework', 'SQL'],
#  ['OpenStack', 'Linux', 'Python', 'Ansible', 'PostgreSQL'],
#  None,
#  None,
#  None,
#  ['Android', 'Android SDK', 'Kotlin', 'Java'],
#  None,
#  None,
#  None,
#  ['Python', 'SQL', 'Git', 'C#', 'Flask', 'PostgreSQL'],
#  None,
#  ['Bash',
#   'Git',
#   'Linux',
#   'Python',
#   'SQL',
#   'Kubernetes',
#   'Jenkins',
#   'Java',
#   'Docker',
#   'Bitbucket',
#   'Liquibase'],
#  None,
#  ['SAP ERP', 'Architecture'],
#  None,
#  ['Python', 'SCALA', 'Java', 'SQL', 'Big Data'],
#  None,
#  ['SQL', 'Нагрузочное тестирование', 'Java'],
#  ['Docker',
#   'ELK',
#   'Jenkins',
#   'Kubernetes',
#   'Linux',
#   'Ansible',
#   'OpenShift',
#   'PostgreSQL',
#   'CI/CD'],
#  ['JavaScript', 'ООП', 'SAP BI', 'SAP HANA', 'SAP ERP'],
#  None,
#  ['Python',
#   'Pandas',
#   'PyTorch',
#   'Numpy',
#   'Написание научных статей',
#   'Data Science'],
#  None,
#  None,
#  None,
#  ['Java',
#   'Git',
#   'Spring',
#   'SQL',
#   'Apache Kafka',
#   'WildFly',
#   'Java SE',
#   'REST'],
#  None,
#  ['Git', 'Python', 'Linux', 'PostgreSQL', 'Docker'],
#  ['SAP ERP',
#   'Управление проектами',
#   'SAP PM',
#   'SAP',
#   'Разработка технических заданий'],
#  ['SQL', 'Hadoop', 'Big Data', 'Java', 'Английский язык'],
#  None,
#  None,
#  ['golang', 'Python'],
#  None,
#  None,
#  ...]

# %%
df_skills['skills'] = arr_skill

# %%
df_skills.head(20)
# Out:
#           id                                               name  \
# 0   55415805                     Менеджер по работе с клиентами
# 1   67349462                        Старший клиентский менеджер
# 2   55415496                  Клиентский менеджер прямых продаж
# 3   45790891  Менеджер по работе с ключевыми клиентами малог...
# 4   67911334                               Ассистент Управления
# 5   55889794                             Финансовый консультант
# 6   67608611                                Водитель-инкассатор
# 7   67867647                              Junior UX/UI Дизайнер
# 8   67838397                            HR-координатор (стажер)
# 9   68293849                            Младший бизнес-аналитик
# 10  67595487                     Менеджер по работе с клиентами
# 11  68267115              Junior+/middle JavaScript разработчик
# 12  67887990  Стажер в лабораторию искусственного интеллекта...
# 13  67737477                              Стажер Data Scientist
# 14  67740281                              Менеджер по комплаенс
# 15  45381514     Менеджер по привлечению корпоративных клиентов
# 16  68231729                                  Специалист архива
# 17  67603928                  Старший специалист отдела закупок
# 18  67595888                     Менеджер по работе с клиентами
# 19  67553105      Координатор ИТ-проектов (релизное управление)
#
#                                           description  \
# 0    Сбер — лучший работодатель России. У нас боле...
# 1    Сбер — лучший работодатель России. У нас боле...
# 2    Сбер — лучший работодатель России. У нас боле...
# 3    Сбер — лучший работодатель России. У нас боле...
# 4     Обязанности:      Аналитика по Управлению за...
# 5    Сбер — лучший работодатель России. У нас боле...
# 6     Водители–инкассаторы  это настоящие професси...
# 7     Кто мы?    Мы - команда, которая создает пла...
# 8    В Управление HR-Блока &quot;Технологии&quot; ...
# 9     Немного о направлении:    Блок «Технологии» ...
# 10   Сбер — лучший работодатель России. У нас боле...
# 11    Трайб «ИСУ» набирает команду для разработки ...
# 12        Лаборатория искусственного интеллекта  с...
# 13   Мы ищем Стажера Data Scientist в команду перс...
# 14    Сбер — это более 60 компаний экосистемы и 14...
# 15   Сбер — лучший работодатель России. У нас боле...
# 16    Обязанности      регистрация и размещение на...
# 17   Направление 1 – закупки услуг по направлению ...
# 18   Сбер — лучший работодатель России. У нас боле...
# 19    Обязанности:      координация этапов ИТ-прои...
#
#                                                skills  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3   Прямые продажи, Финансовый анализ, Клиентоорие...
# 4                                                None
# 5                                                None
# 6                                                None
# 7   UX, Figma, Adobe Photoshop, UI, Дизайн интерфе...
# 8   Работа в команде, Грамотная речь, Организаторс...
# 9   MS Visio, SAP BW, Бизнес-анализ, SQL, Управлен...
# 10                 Активные продажи, Холодные продажи
# 11                              HTML, CSS, JavaScript
# 12          Python, Pandas, PyTorch, Machine Learning
# 13                                               None
# 14                                               None
# 15  Холодные продажи, Поиск и привлечение клиентов...
# 16                                               None
# 17                                               None
# 18                 Активные продажи, Холодные продажи
# 19  Управление проектами, Работа в команде, MS Pow...
#
#                 published_at                created_at  \
# 0   2022-07-27T13:48:51+0300  2022-07-27T13:48:51+0300
# 1   2022-07-25T11:48:47+0300  2022-07-25T11:48:47+0300
# 2   2022-07-29T11:49:00+0300  2022-07-29T11:49:00+0300
# 3   2022-07-28T14:40:40+0300  2022-07-28T14:40:40+0300
# 4   2022-07-19T12:11:11+0300  2022-07-19T12:11:11+0300
# 5   2022-07-27T11:48:44+0300  2022-07-27T11:48:44+0300
# 6   2022-07-08T13:04:07+0300  2022-07-08T13:04:07+0300
# 7   2022-07-18T13:04:17+0300  2022-07-18T13:04:17+0300
# 8   2022-07-17T16:24:19+0300  2022-07-17T16:24:19+0300
# 9   2022-07-29T17:05:12+0300  2022-07-29T17:05:12+0300
# 10  2022-07-11T18:00:30+0300  2022-07-11T18:00:30+0300
# 11  2022-07-29T00:19:15+0300  2022-07-29T00:19:15+0300
# 12  2022-07-18T18:18:17+0300  2022-07-18T18:18:17+0300
# 13  2022-07-13T12:57:05+0300  2022-07-13T12:57:05+0300
# 14  2022-07-13T13:45:34+0300  2022-07-13T13:45:34+0300
# 15  2022-07-28T14:40:31+0300  2022-07-28T14:40:31+0300
# 16  2022-07-28T10:41:36+0300  2022-07-28T10:41:36+0300
# 17  2022-07-08T11:31:19+0300  2022-07-08T11:31:19+0300
# 18  2022-07-27T11:48:44+0300  2022-07-27T11:48:44+0300
# 19  2022-07-20T17:51:36+0300  2022-07-20T17:51:36+0300
#
#                                                salary
# 0   {'from': 98800, 'to': None, 'currency': 'RUR',...
# 1   {'from': 98800, 'to': None, 'currency': 'RUR',...
# 2   {'from': 98800, 'to': None, 'currency': 'RUR',...
# 3   {'from': 119300, 'to': None, 'currency': 'RUR'...
# 4                                                None
# 5   {'from': 68400, 'to': None, 'currency': 'RUR',...
# 6   {'from': 76500, 'to': 89500, 'currency': 'RUR'...
# 7                                                None
# 8                                                None
# 9                                                None
# 10  {'from': 98800, 'to': None, 'currency': 'RUR',...
# 11                                               None
# 12  {'from': 53000, 'to': 58000, 'currency': 'RUR'...
# 13                                               None
# 14                                               None
# 15  {'from': 119000, 'to': None, 'currency': 'RUR'...
# 16                                               None
# 17                                               None
# 18  {'from': 98800, 'to': None, 'currency': 'RUR',...
# 19                                               None

# %%
df_skills['published_at'] = df_skills['published_at'].astype("datetime64")

# %%
df_skills.dtypes
# Out:
# id                      object
# name                    object
# description             object
# skills                  object
# published_at    datetime64[ns]
# created_at              object
# salary                  object
# dtype: object

# %%
df_skills["published_at"].value_counts().plot()

# %%
day = df_skills.groupby(df_skills['published_at'].dt.day_name())['id'].count().sort_values(ascending=False)
day.head(7)
# Out:
# published_at
# Monday       257
# Friday       246
# Tuesday      231
# Thursday     213
# Wednesday    208
# Saturday      21
# Sunday         7
# Name: id, dtype: int64

# %%
like = df_skills[df_skills['name'].str.lower().str.contains('python разработчик')]

# %%
like.head()
# Out:
#            id                                               name  \
# 246  54739236                                 Python разработчик
# 401  54721570  Middle Python разработчик в SberDevices (инфра...
# 427  68199440                          Middle Python разработчик
# 433  68021647                                 Python разработчик
# 496  66493031                                 Python разработчик
#
#                                            description  \
# 246   Наша команда занимаемся развитием и сопровожд...
# 401   SberDevices   — молодая IT-компания. Мы заним...
# 427   Привет! Мы разрабатываем продукты для решения...
# 433   Мы – команда SberSource. Наша основная задача...
# 496   В SberData мы создаем централизованное хранил...
#
#                                                 skills published_at  \
# 246                                               None   2022-07-21
# 401           Python, ML, HighLoad, C++, ElasticSearch   2022-07-11
# 427  Python, Docker, Adobe Photoshop, Django Framew...   2022-07-27
# 433    Python, Linux, JavaScript, Git, Английский язык   2022-07-21
# 496  Docker, Работа с базами данных, Big Data, Упра...   2022-07-18
#
#                    created_at salary
# 246  2022-07-21T17:52:18+0300   None
# 401  2022-07-11T13:06:13+0300   None
# 427  2022-07-27T12:29:53+0300   None
# 433  2022-07-21T11:15:50+0300   None
# 496  2022-07-18T09:38:01+0300   None

# %%
len(like)
# Out:
# 6

# %%
aaa = like['skills'].str.split(', ')
merged = []
for i in aaa:
  if i != None:
    merged += i
merged
# Out:
# ['Python',
#  'ML',
#  'HighLoad',
#  'C++',
#  'ElasticSearch',
#  'Python',
#  'Docker',
#  'Adobe Photoshop',
#  'Django Framework',
#  'Redis',
#  'Python',
#  'Linux',
#  'JavaScript',
#  'Git',
#  'Английский язык',
#  'Docker',
#  'Работа с базами данных',
#  'Big Data',
#  'Управление временем']

# %%
pd.DataFrame(merged).value_counts().sort_values(ascending = True).plot(kind='barh')
